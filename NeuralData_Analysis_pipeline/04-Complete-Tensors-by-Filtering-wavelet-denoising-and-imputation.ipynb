# %%
import os
import pickle
import pandas as pd
import numpy as np
from collections import Counter
import matplotlib.pyplot as plt
import datetime
import cedne
import pywt
from tensorly.decomposition import parafac
from tensorly.decomposition import tucker
from tensorly.tenalg import multi_mode_dot
from tensorly import kruskal_to_tensor

# %%
# today = str(datetime.datetime.now()).split(' ')[0]
# outputDir = "Output/" + today + "/"
outputDir = "processed/"

if not os.path.exists(outputDir):
    os.makedirs(outputDir)

num_timepoints = 450

# %%
def wavelet_denoising(signal, wavelet='db4', level=4, threshold_factor=1.):
    coeffs = pywt.wavedec(signal, wavelet, mode='symmetric', level=level)
    
    # Estimate the universal threshold (Median Absolute Deviation)
    sigma = np.median(np.abs(coeffs[-level])) / 0.6745  
    threshold = threshold_factor * sigma * np.sqrt(2 * np.log(len(signal)))
    
    # Apply thresholding
    coeffs[1:] = [pywt.threshold(c, threshold, mode='soft') for c in coeffs[1:]]
    denoised_signal = pywt.waverec(coeffs, wavelet, mode='symmetric')
    
    return denoised_signal

def simpleaxis(axes, every=False, outward=False):
    if not isinstance(axes, (list, np.ndarray)):
        axes = [axes]
    for ax in axes:
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        if (outward):
            ax.spines['bottom'].set_position(('outward', 10))
            ax.spines['left'].set_position(('outward', 10))
        if every:
            ax.spines['bottom'].set_visible(False)
            ax.spines['left'].set_visible(False)
        ax.get_xaxis().tick_bottom()
        ax.get_yaxis().tick_left()
        ax.set_title('')

def suffix_periods(periods):
    return [periods[0]+'-pre', periods[1], periods[2]+'-post']

def getCombinedName(name):
    if name[-1] in ['L', 'R'] and name not in ['RIR', 'ADL', 'AVL', 'OLL', 'ASEL', 'ASER']:
        return name[:-1]
    else:
        return name

def shuffle_axes(arr, axis='all'):
    shuffled_tensor = arr.copy()
    if isinstance(axis, int):
        # Get the dimensions of the tensor
        shape = shuffled_tensor.shape

        # Create a list of all axes except the specified one
        other_axes = list(range(shuffled_tensor.ndim))
        other_axes.remove(axis)

        # Iterate over all combinations of indices for the other axes
        for idx in np.ndindex(*[shape[i] for i in other_axes]):
            # Build a full index for the current slice
            full_idx = list(idx)
            full_idx.insert(axis, slice(None))
            full_idx = tuple(full_idx)

            # Shuffle along the specified axis for the current slice
            np.random.shuffle(shuffled_tensor[full_idx])

    elif isinstance(axis, str):
        if axis == 'all':
            # Flatten the array
            flat_arr = arr.ravel()
            # Shuffle the flattened array
            np.random.shuffle(flat_arr)
            # Reshape the array back to its original shape
            shuffled_tensor = flat_arr.reshape(arr.shape)
        elif axis == 'none':
            pass
    return shuffled_tensor

# %%
pickleDir = 'pickles/'
genotypes = ['N2', 'inx-7-mutant', 'inx-7-rescue']
promoters = ['ncs-1', 'inx-4', 'glr-1', 'acr-5', 'inx-4+mbr-1', 'flp-3p+flp-7p+nmr-1p+sro-1p', 'odr-2(2b)+odr-2(18)p']
stimuli = ['OP-PA-OP', 'OP-Buffer-OP', 'Buffer-PA-Buffer', 'Buffer-Buffer-Buffer', 'OP-gacA-OP']
conditions = ['naive', 'trained']

wormDict = { genotype:{
                    promoter:{
                        stimulus: {
                            condition: {} for condition in conditions
                        } for stimulus in stimuli
                    } for promoter in promoters
                } for genotype in genotypes 
            }

for pf in sorted(os.listdir(pickleDir)):
    print(pf)
    if not pf.startswith('.'):
        genotype, promoter, stimulus, condition, *name = pf.split('_')
        if not all ([genotype in genotypes, promoter in promoters, stimulus in stimuli, condition in conditions]):
            print(genotype in genotypes, promoter in promoters, stimulus in stimuli, condition in conditions, name)
        else:
            with open(pickleDir + pf, 'rb') as po:
                w = pickle.load(po)
                wormDict[genotype][promoter][stimulus][condition].update({w.name:w})

def clean_empty(d):
    """Recursively remove empty dicts from nested structure"""
    if isinstance(d, dict):
        # Recursively clean children
        cleaned = {k: clean_empty(v) for k, v in d.items()}
        # Filter out any keys whose values are empty dicts
        return {k: v for k, v in cleaned.items() if v != {}}
    else:
        return d  

# Clean your wormDict
wormDict = clean_empty(wormDict)
# Out:
# .DS_Store
# N2_acr-5_Buffer-Buffer-Buffer_naive_20240612-ZC3368-naive-buffer-buffer-30s-worm002.cedne
# N2_acr-5_Buffer-Buffer-Buffer_naive_20240612-ZC3368-naive-buffer-buffer-30s-worm004.cedne
# N2_acr-5_Buffer-Buffer-Buffer_naive_20240612-ZC3368-naive-buffer-buffer-30s-worm005.cedne
# N2_acr-5_Buffer-Buffer-Buffer_naive_20240718-ZC3368-naive-buffer-buffer-30s-worm005.cedne
# N2_acr-5_Buffer-Buffer-Buffer_trained_20240612-ZC3368-trained-buffer-buffer-30s-worm001.cedne
# N2_acr-5_Buffer-Buffer-Buffer_trained_20240612-ZC3368-trained-buffer-buffer-30s-worm005.cedne
# N2_acr-5_Buffer-Buffer-Buffer_trained_20240718-ZC3368-trained-buffer-buffer-30s-worm001.cedne
# N2_acr-5_Buffer-Buffer-Buffer_trained_20240718-ZC3368-trained-buffer-buffer-30s-worm005.cedne
# N2_acr-5_Buffer-PA-Buffer_naive_acr-5p 20220315naive-worm1.cedne
# N2_acr-5_Buffer-PA-Buffer_naive_acr-5p image 20220406-naive-worm4.cedne
# N2_acr-5_Buffer-PA-Buffer_naive_acr-5p image 20220411naive-worm4.cedne
# N2_acr-5_Buffer-PA-Buffer_naive_acr-5p image 20220413 naive-worm1.cedne
# N2_acr-5_Buffer-PA-Buffer_trained_acr-5p image 20220413 trained-worm5.cedne
# N2_acr-5_Buffer-PA-Buffer_trained_acr-5p image 20220704trained-worm2.cedne
# N2_acr-5_Buffer-PA-Buffer_trained_acr-5p image 20220704trained-worm4.cedne
# N2_acr-5_Buffer-PA-Buffer_trained_acr-5p image 20220704trained-worm5.cedne
# N2_acr-5_OP-PA-OP_naive_acr-5p image 20220429 naiveworm2.cedne
# N2_acr-5_OP-PA-OP_naive_acr-5p image 20220712naive-worm3.cedne
# N2_acr-5_OP-PA-OP_naive_acr-5p image 20220714 naive-worm1.cedne
# N2_acr-5_OP-PA-OP_naive_acr-5p image 20220714 naive-worm3.cedne
# N2_acr-5_OP-PA-OP_trained_acr-5p image 20220429 trained worm1.cedne
# N2_acr-5_OP-PA-OP_trained_acr-5p image 20220712trained-worm2.cedne
# N2_acr-5_OP-PA-OP_trained_acr-5p image 20220712trained-worm6.cedne
# N2_acr-5_OP-PA-OP_trained_acr-5p-OP-PA-30s-trained-worm4-image 20220714.cedne
# N2_flp-3p+flp-7p+nmr-1p+sro-1p_Buffer-PA-Buffer_naive_20240116-PA-Buffer-naive-worm1.cedne
# N2_flp-3p+flp-7p+nmr-1p+sro-1p_Buffer-PA-Buffer_naive_20240123-PA-Buffer-naive-worm1.cedne
# N2_flp-3p+flp-7p+nmr-1p+sro-1p_Buffer-PA-Buffer_naive_20240124-PA-Buffer-naive-worm6.cedne
# N2_flp-3p+flp-7p+nmr-1p+sro-1p_Buffer-PA-Buffer_naive_ZC4061_20240125_naive_PA_buffer_worm1.cedne
# N2_flp-3p+flp-7p+nmr-1p+sro-1p_Buffer-PA-Buffer_trained_20240123-PA-Buffer-trained-worm3.cedne
# N2_flp-3p+flp-7p+nmr-1p+sro-1p_Buffer-PA-Buffer_trained_20240123-PA-Buffer-trained-worm4.cedne
# N2_flp-3p+flp-7p+nmr-1p+sro-1p_Buffer-PA-Buffer_trained_20240124-PA-Buffer-trained-worm3.cedne
# N2_flp-3p+flp-7p+nmr-1p+sro-1p_Buffer-PA-Buffer_trained_ZC4061_20240125_trained_PA_buffer_worm2.cedne
# N2_flp-3p+flp-7p+nmr-1p+sro-1p_OP-PA-OP_naive_20240304-zc4061-naive-OP-PA-30s-worm002.cedne
# N2_flp-3p+flp-7p+nmr-1p+sro-1p_OP-PA-OP_naive_20240304-zc4061-naive-OP-PA-30s-worm004.cedne
# N2_flp-3p+flp-7p+nmr-1p+sro-1p_OP-PA-OP_naive_20240306-zc4061-naive-OP-PA-30s-worm001.cedne
# N2_flp-3p+flp-7p+nmr-1p+sro-1p_OP-PA-OP_naive_20240312-ZC4061-naive-OP-PA-30s-worm004.cedne
# N2_flp-3p+flp-7p+nmr-1p+sro-1p_OP-PA-OP_trained_20240304-zc4061-trained-OP-PA-30s-worm004.cedne
# N2_flp-3p+flp-7p+nmr-1p+sro-1p_OP-PA-OP_trained_20240307-zc4061-trained-OP-PA-30s-worm004.cedne
# N2_flp-3p+flp-7p+nmr-1p+sro-1p_OP-PA-OP_trained_20240312-ZC4061-trained-OP-PA-30s-worm002.cedne
# N2_flp-3p+flp-7p+nmr-1p+sro-1p_OP-PA-OP_trained_20240402-ZC4061-trained-OP-PA-30s-worm003.cedne
# N2_glr-1_Buffer-Buffer-Buffer_naive_20240704-ZC3292-naive-buffer-buffer-30s-worm004.cedne
# N2_glr-1_Buffer-Buffer-Buffer_naive_20240708-ZC3292-naive-buffer-buffer-30s-worm001.cedne
# N2_glr-1_Buffer-Buffer-Buffer_naive_20240708-ZC3292-naive-buffer-buffer-30s-worm002.cedne
# N2_glr-1_Buffer-Buffer-Buffer_naive_20240708-ZC3292-naive-buffer-buffer-30s-worm005.cedne
# N2_glr-1_Buffer-Buffer-Buffer_trained_20240704-ZC3292-trained-buffer-buffer-30s-worm001.cedne
# N2_glr-1_Buffer-Buffer-Buffer_trained_20240704-ZC3292-trained-buffer-buffer-30s-worm003.cedne
# N2_glr-1_Buffer-Buffer-Buffer_trained_20240708-ZC3292-trained-buffer-buffer-30s-worm001.cedne
# N2_glr-1_Buffer-Buffer-Buffer_trained_20240708-ZC3292-trained-buffer-buffer-30s-worm003.cedne
# N2_glr-1_Buffer-PA-Buffer_naive_20210920-ZC3292-PA-Buffer-30s-naive-worm2.cedne
# N2_glr-1_Buffer-PA-Buffer_naive_20210920-ZC3292-PA-Buffer-30s-naive-worm4.cedne
# N2_glr-1_Buffer-PA-Buffer_naive_20211004-ZC3292-PA-Buffer-30s-naive-worm5.cedne
# N2_glr-1_Buffer-PA-Buffer_naive_20211006-ZC3292-PA-Buffer-30s-naive-worm1.cedne
# N2_glr-1_Buffer-PA-Buffer_trained_20210927-ZC3292-PA-Buffer-30s-trained-worm2.cedne
# N2_glr-1_Buffer-PA-Buffer_trained_20210927-ZC3292-PA-Buffer-30s-trained-worm4.cedne
# N2_glr-1_Buffer-PA-Buffer_trained_ZC3292_20210920_trained_PA_buffer_worm5.cedne
# N2_glr-1_OP-PA-OP_naive_glr-1 image 1026naive-worm5.cedne
# N2_glr-1_OP-PA-OP_naive_glr-1 image 1029naive-worm2.cedne
# N2_glr-1_OP-PA-OP_naive_glr-1 image 1109naive-worm2.cedne
# N2_glr-1_OP-PA-OP_naive_glr-1 image 1110naive-worm3.cedne
# N2_glr-1_OP-PA-OP_trained_glr-1 image 1029trained-worm3.cedne
# N2_glr-1_OP-PA-OP_trained_glr-1 image 1102trained-worm3.cedne
# N2_glr-1_OP-PA-OP_trained_glr-1 image 1102trained-worm4.cedne
# N2_glr-1_OP-PA-OP_trained_glr-1 image 1110-trained-worm5.cedne
# N2_inx-4+mbr-1_Buffer-Buffer-Buffer_naive_20240808-zc3666-naive-buffer-buffer-30s-worm002.cedne
# N2_inx-4+mbr-1_Buffer-Buffer-Buffer_naive_20240813-ZC3666-naive-buffer-buffer-30s-worm001.cedne
# N2_inx-4+mbr-1_Buffer-Buffer-Buffer_naive_20240813-ZC3666-naive-buffer-buffer-30s-worm004.cedne
# N2_inx-4+mbr-1_Buffer-Buffer-Buffer_naive_20240813-ZC3666-naive-buffer-buffer-30s-worm005.cedne
# N2_inx-4+mbr-1_Buffer-Buffer-Buffer_trained_20240813-ZC3666-trained-buffer-buffer-30s-worm001.cedne
# N2_inx-4+mbr-1_Buffer-Buffer-Buffer_trained_20240813-ZC3666-trained-buffer-buffer-30s-worm003.cedne
# N2_inx-4+mbr-1_Buffer-Buffer-Buffer_trained_20240813-ZC3666-trained-buffer-buffer-30s-worm005.cedne
# N2_inx-4+mbr-1_Buffer-PA-Buffer_naive_20220831-mbr-1-inx-4p-naive-PA-Buffer-30s-worm02.cedne
# N2_inx-4+mbr-1_Buffer-PA-Buffer_naive_20220901-mbr-1-inx-4p-naive-PA-Buffer-30s-worm004.cedne
# N2_inx-4+mbr-1_Buffer-PA-Buffer_naive_20220901-mbr-1-inx-4p-naive-PA-Buffer-30s-worm005.cedne
# N2_inx-4+mbr-1_Buffer-PA-Buffer_naive_20220914-inx-4+mbr-1p-naive-PA-Buffer-worm2.cedne
# N2_inx-4+mbr-1_Buffer-PA-Buffer_trained_20220914-mbr-1-inx-4p-trained-PA-Buffer-30s-worm01.cedne
# N2_inx-4+mbr-1_Buffer-PA-Buffer_trained_20220915-mbr-1-inx-4p-trained-PA-Buffer-30s-worm01.cedne
# N2_inx-4+mbr-1_Buffer-PA-Buffer_trained_20220916-inx-4+mbr-1p-trained-PA-Buffer-worm2.cedne
# N2_inx-4+mbr-1_OP-PA-OP_naive_inx-4+mbr-1p 20221011 naive-worm6.cedne
# N2_inx-4+mbr-1_OP-PA-OP_naive_inx-4+mbr-1p 20221012 naive-worm3.cedne
# N2_inx-4+mbr-1_OP-PA-OP_naive_inx-4+mbr-1p 20221013naive-worm2.cedne
# N2_inx-4+mbr-1_OP-PA-OP_naive_inx-4+mbr-1p image 20221006naive-worm2.cedne
# N2_inx-4+mbr-1_OP-PA-OP_trained_inx-4+mbr-1p 20221014trained-worm4.cedne
# N2_inx-4+mbr-1_OP-PA-OP_trained_inx-4+mbr-1p 20221014trained-worm5.cedne
# N2_inx-4+mbr-1_OP-PA-OP_trained_inx-4+mbr-1p image 20221004trained-worm1.cedne
# N2_inx-4+mbr-1_OP-PA-OP_trained_inx-4+mbr-1p image 20221004trained-worm2.cedne
# N2_inx-4_Buffer-PA-Buffer_naive_inx-4 image 20220118naive-worm1.cedne
# N2_inx-4_Buffer-PA-Buffer_naive_inx-4 image 20220120naive-worm3.cedne
# N2_inx-4_Buffer-PA-Buffer_naive_inx-4 image 20220124naive-worm2.cedne
# N2_inx-4_Buffer-PA-Buffer_naive_inx-4 image 20220124naive-worm4.cedne
# N2_inx-4_Buffer-PA-Buffer_trained_inx-4 image 20220112 trained-worm1.cedne
# N2_inx-4_Buffer-PA-Buffer_trained_inx-4 image 20220112 trained-worm4.cedne
# N2_inx-4_Buffer-PA-Buffer_trained_inx-4 image 20220118trained-worm4.cedne
# N2_inx-4_Buffer-PA-Buffer_trained_inx-4 image 20220120trained-worm3.cedne
# N2_inx-4_OP-PA-OP_naive_inx-4 image 20220204naive-worm3.cedne
# N2_inx-4_OP-PA-OP_naive_inx-4 image 20220207naive-worm1.cedne
# N2_inx-4_OP-PA-OP_naive_inx-4 image 20220208 naive-worm3.cedne
# N2_inx-4_OP-PA-OP_trained_inx-4 image 20220202 trained-worm4.cedne
# N2_inx-4_OP-PA-OP_trained_inx-4 image 20220208 trained-worm2.cedne
# N2_inx-4_OP-PA-OP_trained_inx-4 image 20220210 trained worm3.cedne
# N2_inx-4_OP-PA-OP_trained_inx-4 image 20220211 trained worm3.cedne
# N2_ncs-1_Buffer-Buffer-Buffer_naive_20240606-ZC3305-naive-Buffer-buffer-30s-worm001.cedne
# N2_ncs-1_Buffer-Buffer-Buffer_naive_20240606-ZC3305-naive-Buffer-buffer-30s-worm003.cedne
# N2_ncs-1_Buffer-Buffer-Buffer_naive_20240606-ZC3305-naive-Buffer-buffer-30s-worm005.cedne
# N2_ncs-1_Buffer-Buffer-Buffer_naive_20240709-ZC3305-naive-buffer-buffer-30s-worm05.cedne
# N2_ncs-1_Buffer-Buffer-Buffer_trained_20240606-ZC3305-trained-Buffer-buffer-30s-worm003.cedne
# N2_ncs-1_Buffer-Buffer-Buffer_trained_20240606-ZC3305-trained-Buffer-buffer-30s-worm004.cedne
# N2_ncs-1_Buffer-Buffer-Buffer_trained_20240606-ZC3305-trained-Buffer-buffer-30s-worm005.cedne
# N2_ncs-1_Buffer-Buffer-Buffer_trained_20240709-ZC3305-trained-buffer-buffer-30s-worm04.cedne
# N2_ncs-1_Buffer-PA-Buffer_naive_ncs-1p 20220812 naive-worm3.cedne
# N2_ncs-1_Buffer-PA-Buffer_naive_ncs-1p 20221101 naive-worm1.cedne
# N2_ncs-1_Buffer-PA-Buffer_naive_ncs-1p 20221101 naive-worm5.cedne
# N2_ncs-1_Buffer-PA-Buffer_naive_ncs-1p 20221103 naive-worm1.cedne
# N2_ncs-1_Buffer-PA-Buffer_trained_ncs-1p 20221101 trained-worm4.cedne
# N2_ncs-1_Buffer-PA-Buffer_trained_ncs-1p 20221103 trained-worm3.cedne
# N2_ncs-1_Buffer-PA-Buffer_trained_ncs-1p 20221107 trained-worm1.cedne
# N2_ncs-1_Buffer-PA-Buffer_trained_ncs-1p 20221107 trained-worm5.cedne
# N2_ncs-1_OP-Buffer-OP_naive_ncs-1p_20240404-naive-OP_buf_OP-worm002.cedne
# N2_ncs-1_OP-Buffer-OP_naive_ncs-1p_20240404-naive-OP_buf_OP-worm004.cedne
# N2_ncs-1_OP-Buffer-OP_naive_ncs-1p_20240408-naive-OP_buf_OP-worm001.cedne
# N2_ncs-1_OP-Buffer-OP_naive_ncs-1p_20240416-naive-OP_buf_OP-worm002.cedne
# N2_ncs-1_OP-Buffer-OP_trained_20240402-ZC3305_ncs1-trained-OP_buf_OP-worm001.cedne
# N2_ncs-1_OP-Buffer-OP_trained_ncs-1p_20240404-trained-OP_buf_OP-worm002.cedne
# N2_ncs-1_OP-Buffer-OP_trained_ncs-1p_20240408-trained-OP_buf_OP-worm002.cedne
# N2_ncs-1_OP-Buffer-OP_trained_ncs-1p_20240416-trained-OP_buf_OP-worm002.cedne
# N2_ncs-1_OP-PA-OP_naive_ncs-1p 20230330 naive-worm3.cedne
# N2_ncs-1_OP-PA-OP_naive_ncs-1p 20230331 naive-worm3.cedne
# N2_ncs-1_OP-PA-OP_naive_ncs-1p 20230331 naive-worm5.cedne
# N2_ncs-1_OP-PA-OP_naive_ncs-1p 20230404 naive-worm5.cedne
# N2_ncs-1_OP-PA-OP_trained_ncs-1p 20230330 trained-worm1.cedne
# N2_ncs-1_OP-PA-OP_trained_ncs-1p 20230330 trained-worm2.cedne
# N2_ncs-1_OP-PA-OP_trained_ncs-1p 20230404 trained-worm1.cedne
# N2_ncs-1_OP-PA-OP_trained_ncs-1p 20230404 trained-worm5.cedne
# N2_ncs-1_OP-gacA-OP_naive_ncs-1p_20240521-naive-OP_gacA_OP-worm002.cedne
# N2_ncs-1_OP-gacA-OP_naive_ncs-1p_20240523-naive-OP_gacA_OP-worm002.cedne
# N2_ncs-1_OP-gacA-OP_naive_ncs-1p_20240529-naive-OP_gacA_OP-worm003.cedne
# N2_ncs-1_OP-gacA-OP_naive_ncs-1p_20240530-naive-OP_gacA_OP-worm003.cedne
# N2_ncs-1_OP-gacA-OP_trained_ncs-1p_20240521-trained-OP_gacA_OP-worm002.cedne
# N2_ncs-1_OP-gacA-OP_trained_ncs-1p_20240523-trained-OP_gacA_OP-worm001.cedne
# N2_ncs-1_OP-gacA-OP_trained_ncs-1p_20240530-trained-OP_gacA_OP-worm004.cedne
# N2_odr-2(2b)+odr-2(18)p_Buffer-Buffer-Buffer_naive_20240806-ZC4164-naive-buffer-buffer-30s-worm001.cedne
# N2_odr-2(2b)+odr-2(18)p_Buffer-Buffer-Buffer_naive_20240806-ZC4164-naive-buffer-buffer-30s-worm003.cedne
# N2_odr-2(2b)+odr-2(18)p_Buffer-Buffer-Buffer_naive_20240820-odr-2(2b+18)-L1-naive-buffer-buffer-30s-worm003.cedne
# N2_odr-2(2b)+odr-2(18)p_Buffer-Buffer-Buffer_naive_20240820-odr-2(2b+18)-L1-naive-buffer-buffer-30s-worm005.cedne
# N2_odr-2(2b)+odr-2(18)p_Buffer-Buffer-Buffer_trained_20240806-ZC4164-trained-buffer-buffer-30s-worm003.cedne
# N2_odr-2(2b)+odr-2(18)p_Buffer-Buffer-Buffer_trained_20240820-odr-2(2b+18)-L1-trained-buffer-buffer-30s-worm002.cedne
# N2_odr-2(2b)+odr-2(18)p_Buffer-Buffer-Buffer_trained_20250324-ZC4164-trained-buffer-buffer-30s-worm03.cedne
# N2_odr-2(2b)+odr-2(18)p_Buffer-Buffer-Buffer_trained_20250324-ZC4164-trained-buffer-buffer-30s-worm04.cedne
# N2_odr-2(2b)+odr-2(18)p_Buffer-PA-Buffer_naive_20250408-ZC4164-naive-PA-Buffer-30s-worm004.cedne
# N2_odr-2(2b)+odr-2(18)p_Buffer-PA-Buffer_naive_20250409-ZC4164-naive-PA-Buffer-30s-worm003.cedne
# N2_odr-2(2b)+odr-2(18)p_Buffer-PA-Buffer_naive_20250422-ZC4164-naive-PA-buffer-30s-worm003.cedne
# N2_odr-2(2b)+odr-2(18)p_Buffer-PA-Buffer_naive_20250423-ZC4164-naive-PA-Buffer-30s-worm001.cedne
# N2_odr-2(2b)+odr-2(18)p_Buffer-PA-Buffer_trained_20250408-ZC4164-trained-PA-Buffer-30s-worm001.cedne
# N2_odr-2(2b)+odr-2(18)p_Buffer-PA-Buffer_trained_20250409-ZC4164-trained-PA-Buffer-30s-worm002.cedne
# N2_odr-2(2b)+odr-2(18)p_Buffer-PA-Buffer_trained_20250409-ZC4164-trained-PA-Buffer-30s-worm004.cedne
# N2_odr-2(2b)+odr-2(18)p_Buffer-PA-Buffer_trained_20250422-ZC4164-trained-PA-buffer-30s-worm004.cedne
# N2_odr-2(2b)+odr-2(18)p_OP-PA-OP_naive_20250423-ZC4164-Naive-OP-PA-worm003.cedne
# N2_odr-2(2b)+odr-2(18)p_OP-PA-OP_naive_20250429-ZC4164-Naive-OP-PA-30s-worm008.cedne
# N2_odr-2(2b)+odr-2(18)p_OP-PA-OP_naive_20250429-ZC4164-Naive-OP-PA-worm003.cedne
# N2_odr-2(2b)+odr-2(18)p_OP-PA-OP_naive_20250430-ZC4164-Naive-OP-PA-worm001.cedne
# N2_odr-2(2b)+odr-2(18)p_OP-PA-OP_trained_20250429-ZC4164-Trained-OP-PA-worm002.cedne
# N2_odr-2(2b)+odr-2(18)p_OP-PA-OP_trained_20250430-ZC4164-Trained-OP-PA-worm001.cedne
# N2_odr-2(2b)+odr-2(18)p_OP-PA-OP_trained_20250430-ZC4164-Trained-OP-PA-worm003.cedne
# inx-7-mutant_ncs-1_OP-PA-OP_naive_20241126-ZC4255-naive-OP-PA-30s-worm01.cedne
# inx-7-mutant_ncs-1_OP-PA-OP_naive_20241204-ZC4255-naive-OP-PA-30s-worm003.cedne
# inx-7-mutant_ncs-1_OP-PA-OP_naive_20241204-ZC4255-naive-OP-PA-30s-worm004.cedne
# inx-7-mutant_ncs-1_OP-PA-OP_naive_20250501-ZC4255-naive-OP-PA-30s-worm002.cedne
# inx-7-mutant_ncs-1_OP-PA-OP_trained_20241204-ZC4255-trained-OP-PA-30s-worm003.cedne
# inx-7-mutant_ncs-1_OP-PA-OP_trained_20250501-ZC4255-trained-OP-PA-30s-worm002.cedne
# inx-7-mutant_ncs-1_OP-PA-OP_trained_20250507-ZC4255-trained-OP-PA-30s-worm001.cedne
# inx-7-rescue_ncs-1_OP-PA-OP_naive_20241126-ZC4251-naive-OP-PA-30s-worm001.cedne
# inx-7-rescue_ncs-1_OP-PA-OP_naive_20241204-ZC4251-naive-OP-PA-30s-worm002.cedne
# inx-7-rescue_ncs-1_OP-PA-OP_naive_20250501-ZC4251-naive-OP-PA-30s-worm001.cedne
# inx-7-rescue_ncs-1_OP-PA-OP_naive_raw_results-20241126-ZC4251-naive-PA-OP-30s-worm002.cedne
# inx-7-rescue_ncs-1_OP-PA-OP_trained_20241126-ZC4251-trained-OP-PA-30s-worm02.cedne
# inx-7-rescue_ncs-1_OP-PA-OP_trained_20241205-ZC4251-trained-OP-PA-30s-worm001.cedne
# inx-7-rescue_ncs-1_OP-PA-OP_trained_20250507-ZC4251-trained-OP-PA-30s-worm002.cedne
# inx-7-rescue_ncs-1_OP-PA-OP_trained_20250507-ZC4251-trained-OP-PA-30s-worm003.cedne

# %%
genotype_filter = genotypes
promoter_filter = promoters
stimulus_filter = stimuli#['Buffer-Buffer-Buffer']
condition_filter = conditions

n_per_cond={}
for genotype in wormDict:
    n_per_cond[genotype] = {}
    for promoter in wormDict[genotype]:
        if promoter in promoter_filter:
            n_per_cond[genotype][promoter] = {}
            for stimulus in wormDict[genotype][promoter]:
                if stimulus in stimulus_filter:
                    n_per_cond[genotype][promoter][stimulus] = {} 
                    for condition in wormDict[genotype][promoter][stimulus]:
                        if not condition in n_per_cond[genotype][promoter][stimulus]:
                            n_per_cond[genotype][promoter][stimulus][condition] = {}
                        for wname,w in wormDict[genotype][promoter][stimulus][condition].items():
                            n_per_cond[genotype][promoter][stimulus][condition][wname] = []
                            nn = w.networks[condition]
                            tn=[]
                            for n in nn.neurons:
                                m = getCombinedName(n)
                                if len(nn.neurons[n].trial):
                                        tn.append(m)
                            n_per_cond[genotype][promoter][stimulus][condition][wname]+=tn

# %%
# wormDict_copy = copy.deepcopy(wormDict)
wormDict_copy = wormDict

# %%
## Filtering neurons by minimum number of neurons necessary.

def filter_by_min_neurons(num_neurs_cond, min_neuron_num=8):
    all_neus_cond = {}
    total_neus_cond = {}
    all_neus = []
    for condition in num_neurs_cond: 
        if not condition in all_neus_cond:
            all_neus_cond[condition] = []
        for w,tn in num_neurs_cond[condition].items():
            all_neus+= tn
            all_neus_cond[condition]+=tn
        c = Counter(all_neus_cond[condition])
        total_neus_cond[condition] = c
        set_all_neus_cond = set(c.keys())
        for n in c:
            if c[n]<min_neuron_num:
                set_all_neus_cond.remove(n)
        all_neus_cond[condition] = set(set_all_neus_cond)

    all_neus_set = set(all_neus)
    for condition in all_neus_cond:
            all_neus_set = all_neus_set.intersection(all_neus_cond[condition])
    
    return all_neus_set, total_neus_cond


def plot_histogram_of_neurons(total_neus_cond):
    color_cond = ['gray', 'orange']
    print(len(total_neus_cond))
    f, ax = plt.subplots(nrows=2, ncols = len(total_neus_cond), figsize=(len(total_neus_cond)*5,6), sharex=True, sharey=True)
    for i,exp in enumerate(total_neus_cond):
        for j,cond in enumerate(total_neus_cond[exp]):
            if len(total_neus_cond)>1:
                neu_names = total_neus_cond[exp][cond].keys()
                print(j, neu_names, [total_neus_cond[exp][cond][n] for n in neu_names])
                ax[j,i].bar(neu_names, [total_neus_cond[exp][cond][n] for n in neu_names], color=color_cond[j])
                ax[j,i].set_xticks(range(len(total_neus_cond[exp][cond].keys())), neu_names , rotation=45)
                simpleaxis(ax[j,i])
                ax[j,i].set_title(f'{exp}-{cond}')
            else:
                neu_names = total_neus_cond[exp][cond].keys()
                ax[j].bar(neu_names, [total_neus_cond[exp][cond][n] for n in neu_names], color=color_cond[j])
                ax[j].set_xticks(range(len(total_neus_cond[exp][cond].keys())), neu_names, rotation=45)
                simpleaxis(ax[j])
                ax[j].set_title(f'{exp}-{cond}') 
    plt.show()

# min_neuron_num = 8 # Minimum representation of a neuron
min_neuron_num = 0 # Minimum representation of a neuron, set to 0 for the demo
# fracThreshold = 0.66 # Minimum neuron coverage for a given worm
fracThreshold = 0.2 # Minimum neuron coverage for a given worm

all_neurs_set = {}
total_neurs_set = {}
for genotype in n_per_cond:
    all_neurs_set [genotype] = {}
    total_neurs_set[genotype] = {}
    for promoter in n_per_cond[genotype]:
        all_neurs_set [genotype][promoter] = {}
        total_neurs_set[genotype][promoter] = {}
        for stimulus in n_per_cond[genotype][promoter]:
            print(genotype, promoter, stimulus)
            all_neus_set, by_condition = filter_by_min_neurons(n_per_cond[genotype][promoter][stimulus], min_neuron_num)          
            if all(len(by_condition[cond]) for cond in by_condition):
                total_neurs_set[genotype][promoter][stimulus] = by_condition
            else:
                continue
            if len(all_neus_set):
                frac = []
                for condition in n_per_cond[genotype][promoter][stimulus]: 
                    for w,tn in n_per_cond[genotype][promoter][stimulus][condition].items():
                        frac.append(len(all_neus_set.intersection(set(tn)))/len(all_neus_set))
                        if frac[-1]<fracThreshold:
                            if w in wormDict_copy[genotype][promoter][stimulus][condition]: 
                                wormDict_copy[genotype][promoter][stimulus][condition].pop(w)
                all_neurs_set[genotype][promoter][stimulus] = sorted(list(all_neus_set))
                bins = np.linspace(0,1,30)
                f, ax = plt.subplots(figsize=(3,3))
                ax.hist(frac, bins=bins, color='gray')
                ax.axvline(x=fracThreshold, linestyle='--', color='k')
                simpleaxis(ax)
                ax.set_xlabel("Fraction recorded out of ")
                ax.set_ylabel("# worms")
                plt.show()
        if len(total_neurs_set[genotype][promoter]):
            plot_histogram_of_neurons(total_neurs_set[genotype][promoter])
# Out:
# N2 ncs-1 OP-PA-OP
# N2 ncs-1 OP-Buffer-OP
# N2 ncs-1 Buffer-PA-Buffer
# N2 ncs-1 Buffer-Buffer-Buffer
# N2 ncs-1 OP-gacA-OP
# 5
# 0 dict_keys(['ASG', 'ASI', 'AFD', 'AWA', 'AWB', 'AWC', 'ASEL', 'ASER', 'ADF', 'ASH', 'BAG', 'OLL', 'SAAV', 'AVK', 'ADL', 'SAAD', 'AIY', 'RMG']) [7, 7, 7, 6, 5, 7, 3, 4, 5, 4, 7, 5, 4, 3, 1, 2, 1, 2]
# 1 dict_keys(['ASG', 'ASI', 'AFD', 'AWA', 'AWB', 'AWC', 'ASEL', 'ASH', 'BAG', 'OLL', 'RMG', 'SAAV', 'AVK', 'ASK', 'ASER', 'ADF', 'ADL', 'AIY', 'SAAD']) [7, 6, 8, 6, 6, 8, 4, 2, 8, 7, 2, 6, 5, 1, 3, 4, 2, 1, 3]
# 0 dict_keys(['ASG', 'ASI', 'AFD', 'AWA', 'AWB', 'AWC', 'ASER', 'ADF', 'BAG', 'OLL', 'ASEL', 'ASH', 'RMG', 'SAAV', 'AVK', 'SAAD']) [6, 3, 3, 5, 7, 7, 3, 4, 5, 3, 3, 1, 1, 4, 1, 2]
# 1 dict_keys(['ASG', 'ASI', 'AFD', 'AWA', 'AWB', 'AWC', 'BAG', 'OLL', 'SAAV', 'SAAD', 'ASER', 'ADF', 'RMG']) [5, 3, 5, 4, 6, 6, 7, 6, 6, 1, 3, 2, 1]
# 0 dict_keys(['ASG', 'ASI', 'AFD', 'AWA', 'AWC', 'ASEL', 'ASER', 'BAG', 'OLL', 'AIY', 'SAAV', 'SAAD', 'AWB', 'ADF', 'AVK', 'ASK', 'ASH', 'RMG']) [5, 2, 6, 2, 6, 3, 3, 5, 3, 1, 5, 3, 3, 3, 3, 1, 1, 1]
# 1 dict_keys(['ASG', 'AFD', 'AWA', 'AWB', 'AWC', 'ASEL', 'ADF', 'OLL', 'SAAD', 'SAAV', 'AVK', 'ASI', 'ASER', 'ASH', 'BAG', 'RMG']) [5, 4, 3, 4, 5, 3, 4, 5, 4, 5, 4, 2, 1, 2, 5, 1]
# 0 dict_keys(['ASG', 'ASI', 'AFD', 'AWA', 'AWB', 'AWC', 'ASEL', 'ASER', 'ADF', 'ASH', 'BAG', 'FLP', 'OLL', 'RMG', 'SAAD', 'SAAV', 'AVK', 'AIY']) [7, 4, 7, 5, 6, 8, 4, 3, 7, 3, 8, 1, 5, 3, 4, 5, 4, 2]
# 1 dict_keys(['ASK', 'ASG', 'AFD', 'AWB', 'AWC', 'ASEL', 'ASER', 'ADF', 'ASH', 'BAG', 'OLL', 'RMG', 'SAAV', 'AVK', 'AWA', 'SAAD', 'ASI']) [1, 6, 6, 7, 6, 4, 3, 4, 1, 7, 3, 1, 4, 4, 3, 3, 1]
# 0 dict_keys(['ASG', 'ASI', 'AFD', 'AWB', 'AWC', 'ASEL', 'ASER', 'BAG', 'OLL', 'SAAD', 'AVK', 'SAAV', 'AWA', 'ADF', 'ASH']) [5, 2, 7, 4, 4, 2, 4, 5, 3, 4, 3, 2, 1, 1, 1]
# 1 dict_keys(['ASK', 'ASI', 'AFD', 'AWA', 'AWB', 'AWC', 'ASEL', 'BAG', 'OLL', 'SAAV', 'SAAD', 'AVK', 'ASG', 'ASER', 'ASH', 'AIY']) [2, 3, 3, 4, 4, 5, 3, 5, 3, 5, 4, 3, 3, 1, 1, 1]
# N2 inx-4 OP-PA-OP
# N2 inx-4 Buffer-PA-Buffer
# 2
# 0 dict_keys(['ASG', 'ASH', 'FLP', 'OLL', 'AIN', 'ADA', 'RIG', 'RIM', 'AVJ']) [1, 2, 3, 3, 3, 3, 5, 3, 1]
# 1 dict_keys(['ASH', 'FLP', 'AIN', 'ADA', 'RIG', 'RIM', 'OLL', 'BAG', 'AVJ']) [1, 3, 4, 4, 8, 4, 3, 1, 1]
# 0 dict_keys(['AIN', 'ADA', 'RIG', 'RIM', 'ASG', 'FLP', 'OLL', 'ASH', 'RIR']) [4, 4, 8, 4, 2, 3, 3, 1, 1]
# 1 dict_keys(['FLP', 'AIN', 'ADA', 'RIG', 'RIM', 'OLL', 'ASG', 'ASH', 'AVJ']) [2, 4, 4, 8, 4, 2, 1, 1, 1]
# N2 glr-1 OP-PA-OP
# N2 glr-1 Buffer-PA-Buffer
# N2 glr-1 Buffer-Buffer-Buffer
# 3
# 0 dict_keys(['AVD', 'RIM', 'AVE', 'AVB', 'AVA', 'RMDV', 'RME', 'RMD', 'SMDV', 'RIS', 'RIA', 'RMDD', 'SMDD', 'M1']) [2, 4, 3, 3, 4, 4, 3, 3, 3, 1, 1, 2, 2, 2]
# 1 dict_keys(['AVD', 'RIA', 'RIM', 'AVE', 'AVA', 'RME', 'RMDD', 'RMD', 'RMDV', 'SMDD', 'SMDV', 'AVB', 'AVJ']) [3, 2, 4, 4, 4, 3, 4, 4, 4, 4, 3, 3, 1]
# 0 dict_keys(['AVD', 'RIA', 'RIM', 'AVB', 'AVA', 'RMDD', 'RMDV', 'SMDD', 'SMDV', 'AVE', 'RMD', 'RME']) [3, 3, 3, 4, 4, 3, 4, 3, 4, 2, 2, 2]
# 1 dict_keys(['AVE', 'AVA', 'RMDD', 'RMD', 'RMDV', 'SMDD', 'SMDV', 'RIM', 'AVB', 'AIB', 'AVD']) [3, 3, 3, 3, 3, 3, 3, 2, 2, 1, 1]
# 0 dict_keys(['AVG', 'RIG', 'AVD', 'RIM', 'AVE', 'AVB', 'AVA', 'RMDD', 'RMD', 'RMDV', 'SMDD', 'M1', 'RIA', 'SMDV', 'AIB', 'RIS']) [1, 3, 6, 8, 8, 7, 8, 4, 7, 7, 4, 3, 1, 5, 1, 1]
# 1 dict_keys(['AVD', 'RIM', 'AVE', 'AVB', 'AVA', 'RMDD', 'RMD', 'RMDV', 'SMDD', 'SMDV', 'M1', 'RME', 'AIB', 'RIA']) [5, 7, 8, 6, 7, 6, 8, 8, 5, 8, 4, 1, 3, 1]
# N2 acr-5 OP-PA-OP
# N2 acr-5 Buffer-PA-Buffer
# N2 acr-5 Buffer-Buffer-Buffer
# 3
# 0 dict_keys(['ASG', 'CEPD', 'URYD', 'URYV', 'OLL', 'AVF', 'AVH', 'AVG', 'URAD', 'URAV', 'DB01', 'VB02', 'CEPV', 'ALA', 'AVD', 'VB01']) [3, 3, 4, 4, 3, 3, 2, 4, 4, 4, 3, 3, 3, 3, 1, 2]
# 1 dict_keys(['URYD', 'URYV', 'OLL', 'RME', 'URAD', 'RMDV', 'CEPD', 'CEPV', 'ALA', 'AVG', 'URAV', 'VB02', 'ASG', 'AVF', 'AVD', 'DB01', 'VB01', 'AVH', 'DB02']) [4, 3, 3, 2, 4, 1, 3, 3, 3, 3, 3, 3, 2, 4, 2, 1, 2, 1, 1]
# 0 dict_keys(['ASG', 'CEPD', 'CEPV', 'URYD', 'URYV', 'OLL', 'ALA', 'ADA', 'AVF', 'AVG', 'AVD', 'URAD', 'URAV', 'DB01', 'VB02', 'RME']) [3, 3, 4, 4, 4, 4, 3, 3, 1, 2, 3, 4, 4, 2, 3, 2]
# 1 dict_keys(['CEPD', 'CEPV', 'URYD', 'URYV', 'ALA', 'ADA', 'AVF', 'AVG', 'URAV', 'DB01', 'VB02', 'ASG', 'OLL', 'AVH', 'URAD', 'VB01', 'AVD']) [3, 4, 3, 4, 2, 1, 3, 4, 4, 4, 3, 3, 2, 3, 2, 3, 1]
# 0 dict_keys(['ASG', 'CEPD', 'CEPV', 'URYD', 'URYV', 'OLL', 'AIM', 'ALA', 'ADA', 'AVF', 'AVH', 'AVG', 'AVD', 'URAD', 'URAV', 'SMDV', 'DB01', 'VB01', 'VB02', 'RME']) [3, 7, 7, 7, 8, 8, 3, 3, 3, 6, 3, 3, 3, 7, 6, 3, 3, 3, 3, 2]
# 1 dict_keys(['ASG', 'CEPD', 'CEPV', 'URYD', 'URYV', 'OLL', 'AIM', 'ALA', 'AVF', 'AVG', 'URAD', 'URAV', 'SMDV', 'DB01', 'DB02', 'VB02', 'VB01', 'AVH', 'AVD', 'ADA']) [3, 4, 6, 7, 5, 6, 2, 4, 6, 4, 6, 6, 1, 2, 2, 4, 3, 2, 2, 1]
# N2 inx-4+mbr-1 OP-PA-OP
# N2 inx-4+mbr-1 Buffer-PA-Buffer
# N2 inx-4+mbr-1 Buffer-Buffer-Buffer
# 3
# 0 dict_keys(['OLL', 'IL1', 'AIM', 'AIN', 'RIR', 'ADA', 'RIG', 'RIC', 'RIM', 'ASG', 'FLP', 'AVJ', 'RIP']) [5, 3, 3, 5, 2, 6, 7, 5, 6, 2, 5, 2, 2]
# 1 dict_keys(['FLP', 'OLL', 'AIM', 'AIN', 'ADA', 'RIG', 'RIC', 'RIM', 'RIP', 'RIR', 'AVJ', 'ASH', 'IL1']) [3, 4, 4, 4, 4, 8, 4, 6, 2, 1, 1, 1, 1]
# 0 dict_keys(['ASG', 'ADF', 'ASH', 'FLP', 'OLL', 'AIM', 'AIN', 'RIR', 'ADA', 'RIC', 'AVJ', 'RIM', 'RIP', 'RIG', 'BAG']) [2, 1, 3, 3, 4, 4, 5, 4, 4, 5, 3, 5, 2, 6, 1]
# 1 dict_keys(['ASG', 'ASH', 'FLP', 'OLL', 'AIM', 'AIN', 'ADA', 'RIG', 'RIC', 'AVJ', 'RIM', 'RIH', 'RIR', 'RIP']) [2, 3, 3, 3, 3, 3, 3, 6, 3, 1, 3, 1, 2, 1]
# 0 dict_keys(['ASG', 'ASH', 'URX', 'FLP', 'OLL', 'AIM', 'AIN', 'ADA', 'RIG', 'RIC', 'AVJ', 'RIM', 'RIP', 'ADE', 'RIR']) [1, 3, 1, 8, 7, 4, 6, 8, 8, 5, 2, 6, 2, 1, 2]
# 1 dict_keys(['FLP', 'AIM', 'AIN', 'ADA', 'RIG', 'RIC', 'RIM', 'OLL', 'RIR', 'RIP', 'RME', 'ASG', 'AVJ']) [5, 5, 3, 5, 6, 5, 5, 3, 2, 3, 1, 1, 1]
# N2 flp-3p+flp-7p+nmr-1p+sro-1p OP-PA-OP
# N2 flp-3p+flp-7p+nmr-1p+sro-1p Buffer-PA-Buffer
# 2
# 0 dict_keys(['IL1D', 'IL1', 'IL1V', 'AVG', 'SAAV', 'SAAD', 'AVD', 'RIM', 'AVE', 'AVA', 'SMDV', 'SIBV', 'ASI', 'AVF']) [8, 7, 8, 4, 7, 5, 7, 6, 8, 7, 7, 8, 1, 3]
# 1 dict_keys(['IL1D', 'IL1', 'IL1V', 'AVF', 'AVG', 'SAAD', 'SAAV', 'AVD', 'RIM', 'AVE', 'AVA', 'SMDV', 'SIBV', 'SIBD']) [8, 6, 8, 4, 3, 3, 4, 5, 5, 5, 6, 5, 5, 1]
# 0 dict_keys(['IL1D', 'IL1', 'IL1V', 'AVG', 'SAAV', 'AVD', 'RIM', 'AVE', 'AVA', 'SMDV', 'AVF', 'SIBV', 'ASI', 'RME', 'SIBD', 'ADL', 'SAAD']) [5, 6, 7, 4, 4, 3, 5, 5, 5, 3, 5, 4, 3, 1, 2, 1, 1]
# 1 dict_keys(['IL1D', 'IL1', 'IL1V', 'AVF', 'AVG', 'AVD', 'RIM', 'AVE', 'AVA', 'SMDV', 'SAAD', 'RME', 'SIBV', 'SAAV', 'SIBD']) [7, 4, 7, 4, 4, 3, 6, 6, 6, 3, 3, 2, 3, 1, 1]
# N2 odr-2(2b)+odr-2(18)p OP-PA-OP
# N2 odr-2(2b)+odr-2(18)p Buffer-PA-Buffer
# N2 odr-2(2b)+odr-2(18)p Buffer-Buffer-Buffer
# 3
# 0 dict_keys(['OLL', 'IL1D', 'IL1', 'IL1V', 'AIZ', 'RIF', 'AVG', 'AIB', 'RME', 'SMBD', 'SMBV', 'SIAV', 'ASG', 'RIV', 'SIAD', 'IL2D', 'IL2', 'IL2V']) [7, 5, 7, 4, 7, 8, 3, 7, 6, 4, 5, 5, 6, 4, 1, 1, 1, 1]
# 1 dict_keys(['OLL', 'IL1D', 'IL1', 'IL1V', 'AIZ', 'RIF', 'AVG', 'AIB', 'RME', 'SMBD', 'SMBV', 'SIAD', 'SIAV', 'ASG', 'RIV']) [6, 5, 6, 6, 5, 3, 3, 5, 4, 6, 6, 3, 4, 3, 3]
# 0 dict_keys(['ASG', 'OLL', 'IL1D', 'IL1', 'IL1V', 'AIZ', 'RIF', 'AVG', 'AIB', 'RME', 'RIV', 'SMBD', 'SMBV', 'SIAV', 'SIAD', 'AIY']) [4, 5, 5, 5, 6, 4, 8, 4, 5, 5, 5, 4, 5, 5, 2, 1]
# 1 dict_keys(['ASG', 'IL1D', 'IL1', 'IL1V', 'AIZ', 'RIF', 'AVG', 'AIB', 'RME', 'SMBD', 'SMBV', 'SIAV', 'OLL', 'RIV', 'SIAD']) [3, 3, 3, 5, 3, 6, 3, 5, 3, 5, 4, 5, 2, 1, 1]
# 0 dict_keys(['ASG', 'AFD', 'OLL', 'IL1D', 'IL1', 'IL1V', 'AIY', 'AIZ', 'RIF', 'AVG', 'AIB', 'RME', 'RMED', 'RIV', 'SMBD', 'SMBV', 'SIAD', 'SIAV']) [3, 1, 8, 6, 8, 8, 1, 6, 6, 3, 6, 7, 1, 2, 7, 6, 2, 6]
# 1 dict_keys(['ASG', 'IL1D', 'IL1', 'IL1V', 'AIY', 'AIZ', 'AIB', 'RME', 'RIV', 'SMBD', 'SMBV', 'SIAD', 'SIAV', 'OLL', 'RIF', 'AVG', 'RMEV']) [4, 5, 4, 6, 2, 3, 4, 4, 3, 4, 3, 1, 4, 3, 5, 3, 1]
# inx-7-mutant ncs-1 OP-PA-OP
# 1
# inx-7-rescue ncs-1 OP-PA-OP
# 1

# %% [markdown]
# # Denoising the data

# %%
## Denoising data

threshold_factor =  1.47 # Adjustable threshold factor
worm_neu_dict = {}
w_order = {}
worm_neu_dict_nodenoising = {}

for genotype in wormDict_copy:
    worm_neu_dict[genotype] = {}
    worm_neu_dict_nodenoising[genotype] = {}
    w_order[genotype] = {}
    for promoter in wormDict_copy[genotype]:
        worm_neu_dict[genotype][promoter] = {}
        worm_neu_dict_nodenoising[genotype][promoter] = {}
        w_order[genotype][promoter] = {}
        for stimulus in wormDict_copy[genotype][promoter]:
            worm_neu_dict[genotype][promoter][stimulus] = {}
            worm_neu_dict_nodenoising[genotype][promoter][stimulus] = {}
            w_order[genotype][promoter][stimulus] = {}
            if stimulus in all_neurs_set[genotype][promoter]:
                for cond in wormDict_copy[genotype][promoter][stimulus]:
                    if len(wormDict_copy[genotype][promoter][stimulus][cond]) > 0:
                        worm_neu_dict[genotype][promoter][stimulus][cond] = {}
                        worm_neu_dict_nodenoising[genotype][promoter][stimulus][cond] = {}
                        w_order[genotype][promoter][stimulus][cond] = []
                        if len(wormDict_copy[genotype][promoter][stimulus][cond].items()) and stimulus in all_neurs_set[genotype][promoter]:
                            for w_i, (w, worm) in enumerate(sorted(wormDict_copy[genotype][promoter][stimulus][cond].items(), key=lambda x: x[0])):
                                w_order[genotype][promoter][stimulus][cond].append(w)
                                worm_neu_dict[genotype][promoter][stimulus][cond][w] = {m:[] for m in all_neurs_set[genotype][promoter][stimulus]}
                                worm_neu_dict_nodenoising[genotype][promoter][stimulus][cond][w] = {m:[] for m in all_neurs_set[genotype][promoter][stimulus]}
                                for n in worm.networks[cond].neurons:
                                    m = getCombinedName(n)
                                    if len(worm.networks[cond].neurons[n].trial) and m in all_neurs_set[genotype][promoter][stimulus]:
                                        for trial in worm.networks[cond].neurons[n].trial:
                                            denoised_signal = wavelet_denoising(worm.networks[cond].neurons[n].trial[trial].recording, wavelet='db6', level=2, threshold_factor=threshold_factor)
                                            if np.isnan(denoised_signal).any():
                                                print("NaN in denoised signal", genotype, promoter, stimulus, cond, w, n, denoised_signal)
                                                continue
                                            worm_neu_dict[genotype][promoter][stimulus][cond][w][m].append(denoised_signal[:num_timepoints])
                                            worm_neu_dict_nodenoising[genotype][promoter][stimulus][cond][w][m].append( worm.networks[cond].neurons[n].trial[trial].recording[:num_timepoints])

# %%
worm_tensors = {}
n_order = {}
for genotype in worm_neu_dict:
    worm_tensors[genotype] = {}
    n_order[genotype] = {}
    for promoter in worm_neu_dict[genotype]:
        worm_tensors[genotype][promoter] = {}
        n_order[genotype][promoter] = {}
        for stimulus in worm_neu_dict[genotype][promoter]:
            worm_tensors[genotype][promoter][stimulus] = {}
            n_order[genotype][promoter][stimulus] = {}
            for cond in worm_neu_dict[genotype][promoter][stimulus]:
                worm_tensors[genotype][promoter][stimulus][cond] = np.empty((len(all_neurs_set[genotype][promoter][stimulus]), num_timepoints, len(wormDict_copy[genotype][promoter][stimulus][cond])))
                worm_tensors[genotype][promoter][stimulus][cond].fill(np.nan)
                n_order[genotype][promoter][stimulus][cond] = {}
                if len(worm_neu_dict[genotype][promoter][stimulus][cond].items()):
                    for w_i, w in enumerate(worm_neu_dict[genotype][promoter][stimulus][cond]):
                        n_order[genotype][promoter][stimulus][cond][w] = []
                        for m in worm_neu_dict[genotype][promoter][stimulus][cond][w]:
                            if len(worm_neu_dict[genotype][promoter][stimulus][cond][w][m]) >1:
                                worm_tensors[genotype][promoter][stimulus][cond][all_neurs_set[genotype][promoter][stimulus].index(m),:,w_i] = np.nanmean(worm_neu_dict[genotype][promoter][stimulus][cond][w][m], axis=0)
                                n_order[genotype][promoter][stimulus][cond][w].append(m)
                            elif len(worm_neu_dict[genotype][promoter][stimulus][cond][w][m]) == 1:
                                worm_tensors[genotype][promoter][stimulus][cond][all_neurs_set[genotype][promoter][stimulus].index(m),:,w_i] = worm_neu_dict[genotype][promoter][stimulus][cond][w][m][0]
                                n_order[genotype][promoter][stimulus][cond][w].append(m)
                            else:
                                print("No data for", genotype, promoter, stimulus, cond, w, m, worm_neu_dict[genotype][promoter][stimulus][cond][w][m])
# Out:
# No data for N2 ncs-1 OP-PA-OP naive ncs-1p 20230330 naive-worm3 ADL []
# No data for N2 ncs-1 OP-PA-OP naive ncs-1p 20230330 naive-worm3 AIY []
# No data for N2 ncs-1 OP-PA-OP naive ncs-1p 20230330 naive-worm3 RMG []
# No data for N2 ncs-1 OP-PA-OP naive ncs-1p 20230330 naive-worm3 SAAD []
# No data for N2 ncs-1 OP-PA-OP naive ncs-1p 20230331 naive-worm3 AIY []
# No data for N2 ncs-1 OP-PA-OP naive ncs-1p 20230331 naive-worm3 ASEL []
# No data for N2 ncs-1 OP-PA-OP naive ncs-1p 20230331 naive-worm3 ASH []
# No data for N2 ncs-1 OP-PA-OP naive ncs-1p 20230331 naive-worm3 AVK []
# No data for N2 ncs-1 OP-PA-OP naive ncs-1p 20230331 naive-worm3 RMG []
# No data for N2 ncs-1 OP-PA-OP naive ncs-1p 20230331 naive-worm3 SAAD []
# No data for N2 ncs-1 OP-PA-OP naive ncs-1p 20230331 naive-worm5 ADF []
# No data for N2 ncs-1 OP-PA-OP naive ncs-1p 20230331 naive-worm5 ADL []
# No data for N2 ncs-1 OP-PA-OP naive ncs-1p 20230331 naive-worm5 AIY []
# No data for N2 ncs-1 OP-PA-OP naive ncs-1p 20230331 naive-worm5 ASH []
# No data for N2 ncs-1 OP-PA-OP naive ncs-1p 20230331 naive-worm5 RMG []
# No data for N2 ncs-1 OP-PA-OP naive ncs-1p 20230404 naive-worm5 ADL []
# No data for N2 ncs-1 OP-PA-OP trained ncs-1p 20230330 trained-worm1 ADF []
# No data for N2 ncs-1 OP-PA-OP trained ncs-1p 20230330 trained-worm1 ADL []
# No data for N2 ncs-1 OP-PA-OP trained ncs-1p 20230330 trained-worm1 AIY []
# No data for N2 ncs-1 OP-PA-OP trained ncs-1p 20230330 trained-worm1 ASER []
# No data for N2 ncs-1 OP-PA-OP trained ncs-1p 20230330 trained-worm1 SAAD []
# No data for N2 ncs-1 OP-PA-OP trained ncs-1p 20230330 trained-worm2 AIY []
# No data for N2 ncs-1 OP-PA-OP trained ncs-1p 20230330 trained-worm2 RMG []
# No data for N2 ncs-1 OP-PA-OP trained ncs-1p 20230330 trained-worm2 SAAD []
# No data for N2 ncs-1 OP-PA-OP trained ncs-1p 20230404 trained-worm1 ASH []
# No data for N2 ncs-1 OP-PA-OP trained ncs-1p 20230404 trained-worm1 RMG []
# No data for N2 ncs-1 OP-PA-OP trained ncs-1p 20230404 trained-worm5 ADL []
# No data for N2 ncs-1 OP-PA-OP trained ncs-1p 20230404 trained-worm5 AIY []
# No data for N2 ncs-1 OP-PA-OP trained ncs-1p 20230404 trained-worm5 ASH []
# No data for N2 ncs-1 OP-PA-OP trained ncs-1p 20230404 trained-worm5 ASI []
# No data for N2 ncs-1 OP-Buffer-OP naive ncs-1p_20240404-naive-OP_buf_OP-worm002 RMG []
# No data for N2 ncs-1 OP-Buffer-OP naive ncs-1p_20240404-naive-OP_buf_OP-worm002 SAAD []
# No data for N2 ncs-1 OP-Buffer-OP naive ncs-1p_20240404-naive-OP_buf_OP-worm002 SAAV []
# No data for N2 ncs-1 OP-Buffer-OP naive ncs-1p_20240404-naive-OP_buf_OP-worm004 ASER []
# No data for N2 ncs-1 OP-Buffer-OP naive ncs-1p_20240404-naive-OP_buf_OP-worm004 ASI []
# No data for N2 ncs-1 OP-Buffer-OP naive ncs-1p_20240404-naive-OP_buf_OP-worm004 BAG []
# No data for N2 ncs-1 OP-Buffer-OP naive ncs-1p_20240404-naive-OP_buf_OP-worm004 OLL []
# No data for N2 ncs-1 OP-Buffer-OP naive ncs-1p_20240404-naive-OP_buf_OP-worm004 SAAD []
# No data for N2 ncs-1 OP-Buffer-OP naive ncs-1p_20240408-naive-OP_buf_OP-worm001 AFD []
# No data for N2 ncs-1 OP-Buffer-OP naive ncs-1p_20240408-naive-OP_buf_OP-worm001 ASI []
# No data for N2 ncs-1 OP-Buffer-OP naive ncs-1p_20240408-naive-OP_buf_OP-worm001 RMG []
# No data for N2 ncs-1 OP-Buffer-OP naive ncs-1p_20240416-naive-OP_buf_OP-worm002 AFD []
# No data for N2 ncs-1 OP-Buffer-OP naive ncs-1p_20240416-naive-OP_buf_OP-worm002 RMG []
# No data for N2 ncs-1 OP-Buffer-OP trained 20240402-ZC3305_ncs1-trained-OP_buf_OP-worm001 ADF []
# No data for N2 ncs-1 OP-Buffer-OP trained 20240402-ZC3305_ncs1-trained-OP_buf_OP-worm001 ASER []
# No data for N2 ncs-1 OP-Buffer-OP trained 20240402-ZC3305_ncs1-trained-OP_buf_OP-worm001 RMG []
# No data for N2 ncs-1 OP-Buffer-OP trained ncs-1p_20240404-trained-OP_buf_OP-worm002 SAAD []
# No data for N2 ncs-1 OP-Buffer-OP trained ncs-1p_20240408-trained-OP_buf_OP-worm002 ADF []
# No data for N2 ncs-1 OP-Buffer-OP trained ncs-1p_20240408-trained-OP_buf_OP-worm002 AFD []
# No data for N2 ncs-1 OP-Buffer-OP trained ncs-1p_20240408-trained-OP_buf_OP-worm002 ASI []
# No data for N2 ncs-1 OP-Buffer-OP trained ncs-1p_20240408-trained-OP_buf_OP-worm002 AWA []
# No data for N2 ncs-1 OP-Buffer-OP trained ncs-1p_20240408-trained-OP_buf_OP-worm002 RMG []
# No data for N2 ncs-1 OP-Buffer-OP trained ncs-1p_20240408-trained-OP_buf_OP-worm002 SAAD []
# No data for N2 ncs-1 OP-Buffer-OP trained ncs-1p_20240416-trained-OP_buf_OP-worm002 RMG []
# No data for N2 ncs-1 OP-Buffer-OP trained ncs-1p_20240416-trained-OP_buf_OP-worm002 SAAD []
# No data for N2 ncs-1 Buffer-PA-Buffer naive ncs-1p 20220812 naive-worm3 ADF []
# No data for N2 ncs-1 Buffer-PA-Buffer naive ncs-1p 20220812 naive-worm3 ASH []
# No data for N2 ncs-1 Buffer-PA-Buffer naive ncs-1p 20220812 naive-worm3 AVK []
# No data for N2 ncs-1 Buffer-PA-Buffer naive ncs-1p 20220812 naive-worm3 AWB []
# No data for N2 ncs-1 Buffer-PA-Buffer naive ncs-1p 20220812 naive-worm3 RMG []
# No data for N2 ncs-1 Buffer-PA-Buffer naive ncs-1p 20221101 naive-worm1 ASH []
# No data for N2 ncs-1 Buffer-PA-Buffer naive ncs-1p 20221101 naive-worm1 ASI []
# No data for N2 ncs-1 Buffer-PA-Buffer naive ncs-1p 20221101 naive-worm1 AWA []
# No data for N2 ncs-1 Buffer-PA-Buffer naive ncs-1p 20221101 naive-worm1 OLL []
# No data for N2 ncs-1 Buffer-PA-Buffer naive ncs-1p 20221101 naive-worm1 RMG []
# No data for N2 ncs-1 Buffer-PA-Buffer naive ncs-1p 20221101 naive-worm5 ASEL []
# No data for N2 ncs-1 Buffer-PA-Buffer naive ncs-1p 20221101 naive-worm5 ASG []
# No data for N2 ncs-1 Buffer-PA-Buffer naive ncs-1p 20221101 naive-worm5 ASI []
# No data for N2 ncs-1 Buffer-PA-Buffer naive ncs-1p 20221101 naive-worm5 AWA []
# No data for N2 ncs-1 Buffer-PA-Buffer naive ncs-1p 20221103 naive-worm1 ASER []
# No data for N2 ncs-1 Buffer-PA-Buffer naive ncs-1p 20221103 naive-worm1 ASH []
# No data for N2 ncs-1 Buffer-PA-Buffer naive ncs-1p 20221103 naive-worm1 ASI []
# No data for N2 ncs-1 Buffer-PA-Buffer naive ncs-1p 20221103 naive-worm1 RMG []
# No data for N2 ncs-1 Buffer-PA-Buffer naive ncs-1p 20221103 naive-worm1 SAAD []
# No data for N2 ncs-1 Buffer-PA-Buffer trained ncs-1p 20221101 trained-worm4 ASER []
# No data for N2 ncs-1 Buffer-PA-Buffer trained ncs-1p 20221101 trained-worm4 ASH []
# No data for N2 ncs-1 Buffer-PA-Buffer trained ncs-1p 20221101 trained-worm4 ASI []
# No data for N2 ncs-1 Buffer-PA-Buffer trained ncs-1p 20221101 trained-worm4 BAG []
# No data for N2 ncs-1 Buffer-PA-Buffer trained ncs-1p 20221101 trained-worm4 RMG []
# No data for N2 ncs-1 Buffer-PA-Buffer trained ncs-1p 20221103 trained-worm3 ASEL []
# No data for N2 ncs-1 Buffer-PA-Buffer trained ncs-1p 20221103 trained-worm3 RMG []
# No data for N2 ncs-1 Buffer-PA-Buffer trained ncs-1p 20221107 trained-worm1 ASER []
# No data for N2 ncs-1 Buffer-PA-Buffer trained ncs-1p 20221107 trained-worm1 OLL []
# No data for N2 ncs-1 Buffer-PA-Buffer trained ncs-1p 20221107 trained-worm5 ASER []
# No data for N2 ncs-1 Buffer-PA-Buffer trained ncs-1p 20221107 trained-worm5 ASH []
# No data for N2 ncs-1 Buffer-PA-Buffer trained ncs-1p 20221107 trained-worm5 ASI []
# No data for N2 ncs-1 Buffer-PA-Buffer trained ncs-1p 20221107 trained-worm5 AWA []
# No data for N2 ncs-1 Buffer-PA-Buffer trained ncs-1p 20221107 trained-worm5 RMG []
# No data for N2 ncs-1 Buffer-Buffer-Buffer naive 20240606-ZC3305-naive-Buffer-buffer-30s-worm003 ASER []
# No data for N2 ncs-1 Buffer-Buffer-Buffer naive 20240606-ZC3305-naive-Buffer-buffer-30s-worm003 OLL []
# No data for N2 ncs-1 Buffer-Buffer-Buffer naive 20240606-ZC3305-naive-Buffer-buffer-30s-worm003 RMG []
# No data for N2 ncs-1 Buffer-Buffer-Buffer naive 20240606-ZC3305-naive-Buffer-buffer-30s-worm005 ASH []
# No data for N2 ncs-1 Buffer-Buffer-Buffer naive 20240606-ZC3305-naive-Buffer-buffer-30s-worm005 RMG []
# No data for N2 ncs-1 Buffer-Buffer-Buffer trained 20240606-ZC3305-trained-Buffer-buffer-30s-worm003 ASI []
# No data for N2 ncs-1 Buffer-Buffer-Buffer trained 20240606-ZC3305-trained-Buffer-buffer-30s-worm003 AWA []
# No data for N2 ncs-1 Buffer-Buffer-Buffer trained 20240606-ZC3305-trained-Buffer-buffer-30s-worm003 SAAD []
# No data for N2 ncs-1 Buffer-Buffer-Buffer trained 20240606-ZC3305-trained-Buffer-buffer-30s-worm004 ASH []
# No data for N2 ncs-1 Buffer-Buffer-Buffer trained 20240606-ZC3305-trained-Buffer-buffer-30s-worm004 ASI []
# No data for N2 ncs-1 Buffer-Buffer-Buffer trained 20240606-ZC3305-trained-Buffer-buffer-30s-worm004 RMG []
# No data for N2 ncs-1 Buffer-Buffer-Buffer trained 20240606-ZC3305-trained-Buffer-buffer-30s-worm005 ASER []
# No data for N2 ncs-1 Buffer-Buffer-Buffer trained 20240606-ZC3305-trained-Buffer-buffer-30s-worm005 ASH []
# No data for N2 ncs-1 Buffer-Buffer-Buffer trained 20240606-ZC3305-trained-Buffer-buffer-30s-worm005 ASI []
# No data for N2 ncs-1 Buffer-Buffer-Buffer trained 20240606-ZC3305-trained-Buffer-buffer-30s-worm005 RMG []
# No data for N2 ncs-1 Buffer-Buffer-Buffer trained 20240709-ZC3305-trained-buffer-buffer-30s-worm04 ASH []
# No data for N2 ncs-1 Buffer-Buffer-Buffer trained 20240709-ZC3305-trained-buffer-buffer-30s-worm04 OLL []
# No data for N2 ncs-1 Buffer-Buffer-Buffer trained 20240709-ZC3305-trained-buffer-buffer-30s-worm04 RMG []
# No data for N2 ncs-1 Buffer-Buffer-Buffer trained 20240709-ZC3305-trained-buffer-buffer-30s-worm04 SAAV []
# No data for N2 ncs-1 OP-gacA-OP naive ncs-1p_20240521-naive-OP_gacA_OP-worm002 ASH []
# No data for N2 ncs-1 OP-gacA-OP naive ncs-1p_20240521-naive-OP_gacA_OP-worm002 AWA []
# No data for N2 ncs-1 OP-gacA-OP naive ncs-1p_20240521-naive-OP_gacA_OP-worm002 SAAV []
# No data for N2 ncs-1 OP-gacA-OP naive ncs-1p_20240523-naive-OP_gacA_OP-worm002 ASEL []
# No data for N2 ncs-1 OP-gacA-OP naive ncs-1p_20240523-naive-OP_gacA_OP-worm002 ASH []
# No data for N2 ncs-1 OP-gacA-OP naive ncs-1p_20240523-naive-OP_gacA_OP-worm002 ASI []
# No data for N2 ncs-1 OP-gacA-OP naive ncs-1p_20240523-naive-OP_gacA_OP-worm002 AWA []
# No data for N2 ncs-1 OP-gacA-OP naive ncs-1p_20240523-naive-OP_gacA_OP-worm002 AWB []
# No data for N2 ncs-1 OP-gacA-OP naive ncs-1p_20240523-naive-OP_gacA_OP-worm002 SAAV []
# No data for N2 ncs-1 OP-gacA-OP naive ncs-1p_20240529-naive-OP_gacA_OP-worm003 ASH []
# No data for N2 ncs-1 OP-gacA-OP naive ncs-1p_20240529-naive-OP_gacA_OP-worm003 ASI []
# No data for N2 ncs-1 OP-gacA-OP naive ncs-1p_20240529-naive-OP_gacA_OP-worm003 AVK []
# No data for N2 ncs-1 OP-gacA-OP naive ncs-1p_20240529-naive-OP_gacA_OP-worm003 AWA []
# No data for N2 ncs-1 OP-gacA-OP naive ncs-1p_20240529-naive-OP_gacA_OP-worm003 AWC []
# No data for N2 ncs-1 OP-gacA-OP naive ncs-1p_20240530-naive-OP_gacA_OP-worm003 ASEL []
# No data for N2 ncs-1 OP-gacA-OP naive ncs-1p_20240530-naive-OP_gacA_OP-worm003 AVK []
# No data for N2 ncs-1 OP-gacA-OP naive ncs-1p_20240530-naive-OP_gacA_OP-worm003 OLL []
# No data for N2 ncs-1 OP-gacA-OP trained ncs-1p_20240521-trained-OP_gacA_OP-worm002 ASER []
# No data for N2 ncs-1 OP-gacA-OP trained ncs-1p_20240521-trained-OP_gacA_OP-worm002 ASG []
# No data for N2 ncs-1 OP-gacA-OP trained ncs-1p_20240521-trained-OP_gacA_OP-worm002 ASH []
# No data for N2 ncs-1 OP-gacA-OP trained ncs-1p_20240523-trained-OP_gacA_OP-worm001 AVK []
# No data for N2 ncs-1 OP-gacA-OP trained ncs-1p_20240530-trained-OP_gacA_OP-worm004 AFD []
# No data for N2 ncs-1 OP-gacA-OP trained ncs-1p_20240530-trained-OP_gacA_OP-worm004 ASER []
# No data for N2 ncs-1 OP-gacA-OP trained ncs-1p_20240530-trained-OP_gacA_OP-worm004 ASH []
# No data for N2 inx-4 OP-PA-OP naive inx-4 image 20220204naive-worm3 AVJ []
# No data for N2 inx-4 OP-PA-OP naive inx-4 image 20220207naive-worm1 ASH []
# No data for N2 inx-4 OP-PA-OP naive inx-4 image 20220207naive-worm1 AVJ []
# No data for N2 inx-4 OP-PA-OP trained inx-4 image 20220202 trained-worm4 AVJ []
# No data for N2 inx-4 OP-PA-OP trained inx-4 image 20220202 trained-worm4 OLL []
# No data for N2 inx-4 OP-PA-OP trained inx-4 image 20220208 trained-worm2 ASH []
# No data for N2 inx-4 OP-PA-OP trained inx-4 image 20220208 trained-worm2 AVJ []
# No data for N2 inx-4 OP-PA-OP trained inx-4 image 20220208 trained-worm2 FLP []
# No data for N2 inx-4 OP-PA-OP trained inx-4 image 20220210 trained worm3 ASH []
# No data for N2 inx-4 OP-PA-OP trained inx-4 image 20220210 trained worm3 AVJ []
# No data for N2 inx-4 OP-PA-OP trained inx-4 image 20220211 trained worm3 ASH []
# No data for N2 inx-4 Buffer-PA-Buffer naive inx-4 image 20220118naive-worm1 ASG []
# No data for N2 inx-4 Buffer-PA-Buffer naive inx-4 image 20220118naive-worm1 ASH []
# No data for N2 inx-4 Buffer-PA-Buffer naive inx-4 image 20220118naive-worm1 FLP []
# No data for N2 inx-4 Buffer-PA-Buffer naive inx-4 image 20220118naive-worm1 OLL []
# No data for N2 inx-4 Buffer-PA-Buffer naive inx-4 image 20220120naive-worm3 ASH []
# No data for N2 inx-4 Buffer-PA-Buffer naive inx-4 image 20220124naive-worm2 ASH []
# No data for N2 inx-4 Buffer-PA-Buffer naive inx-4 image 20220124naive-worm4 ASG []
# No data for N2 inx-4 Buffer-PA-Buffer trained inx-4 image 20220112 trained-worm1 ASG []
# No data for N2 inx-4 Buffer-PA-Buffer trained inx-4 image 20220112 trained-worm1 ASH []
# No data for N2 inx-4 Buffer-PA-Buffer trained inx-4 image 20220112 trained-worm1 OLL []
# No data for N2 inx-4 Buffer-PA-Buffer trained inx-4 image 20220112 trained-worm4 ASG []
# No data for N2 inx-4 Buffer-PA-Buffer trained inx-4 image 20220112 trained-worm4 ASH []
# No data for N2 inx-4 Buffer-PA-Buffer trained inx-4 image 20220118trained-worm4 FLP []
# No data for N2 inx-4 Buffer-PA-Buffer trained inx-4 image 20220120trained-worm3 ASG []
# No data for N2 inx-4 Buffer-PA-Buffer trained inx-4 image 20220120trained-worm3 ASH []
# No data for N2 inx-4 Buffer-PA-Buffer trained inx-4 image 20220120trained-worm3 FLP []
# No data for N2 inx-4 Buffer-PA-Buffer trained inx-4 image 20220120trained-worm3 OLL []
# No data for N2 glr-1 OP-PA-OP naive glr-1 image 1026naive-worm5 RIA []
# No data for N2 glr-1 OP-PA-OP naive glr-1 image 1026naive-worm5 RMD []
# No data for N2 glr-1 OP-PA-OP naive glr-1 image 1026naive-worm5 RMDD []
# No data for N2 glr-1 OP-PA-OP naive glr-1 image 1026naive-worm5 RME []
# No data for N2 glr-1 OP-PA-OP naive glr-1 image 1026naive-worm5 SMDD []
# No data for N2 glr-1 OP-PA-OP naive glr-1 image 1026naive-worm5 SMDV []
# No data for N2 glr-1 OP-PA-OP naive glr-1 image 1029naive-worm2 RIA []
# No data for N2 glr-1 OP-PA-OP naive glr-1 image 1029naive-worm2 RMDD []
# No data for N2 glr-1 OP-PA-OP naive glr-1 image 1029naive-worm2 SMDD []
# No data for N2 glr-1 OP-PA-OP naive glr-1 image 1109naive-worm2 AVB []
# No data for N2 glr-1 OP-PA-OP naive glr-1 image 1109naive-worm2 AVD []
# No data for N2 glr-1 OP-PA-OP naive glr-1 image 1110naive-worm3 AVD []
# No data for N2 glr-1 OP-PA-OP naive glr-1 image 1110naive-worm3 AVE []
# No data for N2 glr-1 OP-PA-OP naive glr-1 image 1110naive-worm3 RIA []
# No data for N2 glr-1 OP-PA-OP trained glr-1 image 1029trained-worm3 AVB []
# No data for N2 glr-1 OP-PA-OP trained glr-1 image 1102trained-worm3 RIA []
# No data for N2 glr-1 OP-PA-OP trained glr-1 image 1102trained-worm3 RME []
# No data for N2 glr-1 OP-PA-OP trained glr-1 image 1102trained-worm3 SMDV []
# No data for N2 glr-1 OP-PA-OP trained glr-1 image 1110-trained-worm5 AVD []
# No data for N2 glr-1 OP-PA-OP trained glr-1 image 1110-trained-worm5 RIA []
# No data for N2 glr-1 Buffer-PA-Buffer naive 20210920-ZC3292-PA-Buffer-30s-naive-worm2 AVE []
# No data for N2 glr-1 Buffer-PA-Buffer naive 20210920-ZC3292-PA-Buffer-30s-naive-worm2 RMD []
# No data for N2 glr-1 Buffer-PA-Buffer naive 20211006-ZC3292-PA-Buffer-30s-naive-worm1 AVD []
# No data for N2 glr-1 Buffer-PA-Buffer naive 20211006-ZC3292-PA-Buffer-30s-naive-worm1 AVE []
# No data for N2 glr-1 Buffer-PA-Buffer naive 20211006-ZC3292-PA-Buffer-30s-naive-worm1 RIM []
# No data for N2 glr-1 Buffer-PA-Buffer naive 20211006-ZC3292-PA-Buffer-30s-naive-worm1 RMD []
# No data for N2 glr-1 Buffer-PA-Buffer naive 20211006-ZC3292-PA-Buffer-30s-naive-worm1 RMDD []
# No data for N2 glr-1 Buffer-PA-Buffer naive 20211006-ZC3292-PA-Buffer-30s-naive-worm1 SMDD []
# No data for N2 glr-1 Buffer-PA-Buffer trained 20210927-ZC3292-PA-Buffer-30s-trained-worm2 AVB []
# No data for N2 glr-1 Buffer-PA-Buffer trained 20210927-ZC3292-PA-Buffer-30s-trained-worm2 AVD []
# No data for N2 glr-1 Buffer-PA-Buffer trained 20210927-ZC3292-PA-Buffer-30s-trained-worm2 RIM []
# No data for N2 glr-1 Buffer-PA-Buffer trained 20210927-ZC3292-PA-Buffer-30s-trained-worm4 AVD []
# No data for N2 glr-1 Buffer-Buffer-Buffer naive 20240704-ZC3292-naive-buffer-buffer-30s-worm004 AIB []
# No data for N2 glr-1 Buffer-Buffer-Buffer naive 20240704-ZC3292-naive-buffer-buffer-30s-worm004 RIA []
# No data for N2 glr-1 Buffer-Buffer-Buffer naive 20240704-ZC3292-naive-buffer-buffer-30s-worm004 SMDV []
# No data for N2 glr-1 Buffer-Buffer-Buffer naive 20240708-ZC3292-naive-buffer-buffer-30s-worm001 AIB []
# No data for N2 glr-1 Buffer-Buffer-Buffer naive 20240708-ZC3292-naive-buffer-buffer-30s-worm002 M1 []
# No data for N2 glr-1 Buffer-Buffer-Buffer naive 20240708-ZC3292-naive-buffer-buffer-30s-worm002 RIA []
# No data for N2 glr-1 Buffer-Buffer-Buffer naive 20240708-ZC3292-naive-buffer-buffer-30s-worm005 AIB []
# No data for N2 glr-1 Buffer-Buffer-Buffer naive 20240708-ZC3292-naive-buffer-buffer-30s-worm005 RIA []
# No data for N2 glr-1 Buffer-Buffer-Buffer trained 20240704-ZC3292-trained-buffer-buffer-30s-worm001 AIB []
# No data for N2 glr-1 Buffer-Buffer-Buffer trained 20240704-ZC3292-trained-buffer-buffer-30s-worm001 RIA []
# No data for N2 glr-1 Buffer-Buffer-Buffer trained 20240704-ZC3292-trained-buffer-buffer-30s-worm003 AIB []
# No data for N2 glr-1 Buffer-Buffer-Buffer trained 20240704-ZC3292-trained-buffer-buffer-30s-worm003 RIA []
# No data for N2 glr-1 Buffer-Buffer-Buffer trained 20240708-ZC3292-trained-buffer-buffer-30s-worm001 AVD []
# No data for N2 glr-1 Buffer-Buffer-Buffer trained 20240708-ZC3292-trained-buffer-buffer-30s-worm003 AVB []
# No data for N2 glr-1 Buffer-Buffer-Buffer trained 20240708-ZC3292-trained-buffer-buffer-30s-worm003 RIA []
# No data for N2 acr-5 OP-PA-OP naive acr-5p image 20220429 naiveworm2 ALA []
# No data for N2 acr-5 OP-PA-OP naive acr-5p image 20220429 naiveworm2 AVD []
# No data for N2 acr-5 OP-PA-OP naive acr-5p image 20220429 naiveworm2 CEPV []
# No data for N2 acr-5 OP-PA-OP naive acr-5p image 20220429 naiveworm2 VB01 []
# No data for N2 acr-5 OP-PA-OP naive acr-5p image 20220712naive-worm3 ASG []
# No data for N2 acr-5 OP-PA-OP naive acr-5p image 20220712naive-worm3 AVD []
# No data for N2 acr-5 OP-PA-OP naive acr-5p image 20220712naive-worm3 AVH []
# No data for N2 acr-5 OP-PA-OP naive acr-5p image 20220712naive-worm3 CEPD []
# No data for N2 acr-5 OP-PA-OP naive acr-5p image 20220712naive-worm3 DB01 []
# No data for N2 acr-5 OP-PA-OP naive acr-5p image 20220712naive-worm3 VB01 []
# No data for N2 acr-5 OP-PA-OP naive acr-5p image 20220714 naive-worm1 AVF []
# No data for N2 acr-5 OP-PA-OP naive acr-5p image 20220714 naive-worm1 AVH []
# No data for N2 acr-5 OP-PA-OP naive acr-5p image 20220714 naive-worm1 VB02 []
# No data for N2 acr-5 OP-PA-OP naive acr-5p image 20220714 naive-worm3 AVD []
# No data for N2 acr-5 OP-PA-OP naive acr-5p image 20220714 naive-worm3 OLL []
# No data for N2 acr-5 OP-PA-OP trained acr-5p image 20220429 trained worm1 ALA []
# No data for N2 acr-5 OP-PA-OP trained acr-5p image 20220429 trained worm1 ASG []
# No data for N2 acr-5 OP-PA-OP trained acr-5p image 20220429 trained worm1 AVD []
# No data for N2 acr-5 OP-PA-OP trained acr-5p image 20220429 trained worm1 AVF []
# No data for N2 acr-5 OP-PA-OP trained acr-5p image 20220429 trained worm1 AVG []
# No data for N2 acr-5 OP-PA-OP trained acr-5p image 20220429 trained worm1 AVH []
# No data for N2 acr-5 OP-PA-OP trained acr-5p image 20220429 trained worm1 CEPD []
# No data for N2 acr-5 OP-PA-OP trained acr-5p image 20220429 trained worm1 CEPV []
# No data for N2 acr-5 OP-PA-OP trained acr-5p image 20220429 trained worm1 DB01 []
# No data for N2 acr-5 OP-PA-OP trained acr-5p image 20220429 trained worm1 URAV []
# No data for N2 acr-5 OP-PA-OP trained acr-5p image 20220429 trained worm1 VB01 []
# No data for N2 acr-5 OP-PA-OP trained acr-5p image 20220429 trained worm1 VB02 []
# No data for N2 acr-5 OP-PA-OP trained acr-5p image 20220712trained-worm2 ASG []
# No data for N2 acr-5 OP-PA-OP trained acr-5p image 20220712trained-worm2 AVD []
# No data for N2 acr-5 OP-PA-OP trained acr-5p image 20220712trained-worm2 AVF []
# No data for N2 acr-5 OP-PA-OP trained acr-5p image 20220712trained-worm2 AVH []
# No data for N2 acr-5 OP-PA-OP trained acr-5p image 20220712trained-worm2 DB01 []
# No data for N2 acr-5 OP-PA-OP trained acr-5p image 20220712trained-worm2 VB01 []
# No data for N2 acr-5 OP-PA-OP trained acr-5p image 20220712trained-worm6 AVH []
# No data for N2 acr-5 OP-PA-OP trained acr-5p-OP-PA-30s-trained-worm4-image 20220714 DB01 []
# No data for N2 acr-5 OP-PA-OP trained acr-5p-OP-PA-30s-trained-worm4-image 20220714 OLL []
# No data for N2 acr-5 OP-PA-OP trained acr-5p-OP-PA-30s-trained-worm4-image 20220714 URYV []
# No data for N2 acr-5 Buffer-PA-Buffer naive acr-5p image 20220406-naive-worm4 AVF []
# No data for N2 acr-5 Buffer-PA-Buffer naive acr-5p image 20220411naive-worm4 ADA []
# No data for N2 acr-5 Buffer-PA-Buffer naive acr-5p image 20220411naive-worm4 ALA []
# No data for N2 acr-5 Buffer-PA-Buffer naive acr-5p image 20220411naive-worm4 ASG []
# No data for N2 acr-5 Buffer-PA-Buffer naive acr-5p image 20220411naive-worm4 AVD []
# No data for N2 acr-5 Buffer-PA-Buffer naive acr-5p image 20220411naive-worm4 AVF []
# No data for N2 acr-5 Buffer-PA-Buffer naive acr-5p image 20220411naive-worm4 AVG []
# No data for N2 acr-5 Buffer-PA-Buffer naive acr-5p image 20220411naive-worm4 CEPD []
# No data for N2 acr-5 Buffer-PA-Buffer naive acr-5p image 20220411naive-worm4 DB01 []
# No data for N2 acr-5 Buffer-PA-Buffer naive acr-5p image 20220411naive-worm4 VB02 []
# No data for N2 acr-5 Buffer-PA-Buffer naive acr-5p image 20220413 naive-worm1 AVF []
# No data for N2 acr-5 Buffer-PA-Buffer naive acr-5p image 20220413 naive-worm1 AVG []
# No data for N2 acr-5 Buffer-PA-Buffer naive acr-5p image 20220413 naive-worm1 DB01 []
# No data for N2 acr-5 Buffer-PA-Buffer trained acr-5p image 20220413 trained-worm5 ASG []
# No data for N2 acr-5 Buffer-PA-Buffer trained acr-5p image 20220413 trained-worm5 AVD []
# No data for N2 acr-5 Buffer-PA-Buffer trained acr-5p image 20220413 trained-worm5 OLL []
# No data for N2 acr-5 Buffer-PA-Buffer trained acr-5p image 20220413 trained-worm5 URAD []
# No data for N2 acr-5 Buffer-PA-Buffer trained acr-5p image 20220704trained-worm2 ADA []
# No data for N2 acr-5 Buffer-PA-Buffer trained acr-5p image 20220704trained-worm2 ALA []
# No data for N2 acr-5 Buffer-PA-Buffer trained acr-5p image 20220704trained-worm2 AVD []
# No data for N2 acr-5 Buffer-PA-Buffer trained acr-5p image 20220704trained-worm4 ADA []
# No data for N2 acr-5 Buffer-PA-Buffer trained acr-5p image 20220704trained-worm4 ALA []
# No data for N2 acr-5 Buffer-PA-Buffer trained acr-5p image 20220704trained-worm4 AVD []
# No data for N2 acr-5 Buffer-PA-Buffer trained acr-5p image 20220704trained-worm4 URYD []
# No data for N2 acr-5 Buffer-PA-Buffer trained acr-5p image 20220704trained-worm5 ADA []
# No data for N2 acr-5 Buffer-PA-Buffer trained acr-5p image 20220704trained-worm5 AVF []
# No data for N2 acr-5 Buffer-PA-Buffer trained acr-5p image 20220704trained-worm5 CEPD []
# No data for N2 acr-5 Buffer-PA-Buffer trained acr-5p image 20220704trained-worm5 OLL []
# No data for N2 acr-5 Buffer-PA-Buffer trained acr-5p image 20220704trained-worm5 URAD []
# No data for N2 acr-5 Buffer-PA-Buffer trained acr-5p image 20220704trained-worm5 VB02 []
# No data for N2 acr-5 Buffer-Buffer-Buffer naive 20240612-ZC3368-naive-buffer-buffer-30s-worm005 AIM []
# No data for N2 acr-5 Buffer-Buffer-Buffer naive 20240718-ZC3368-naive-buffer-buffer-30s-worm005 ADA []
# No data for N2 acr-5 Buffer-Buffer-Buffer naive 20240718-ZC3368-naive-buffer-buffer-30s-worm005 AIM []
# No data for N2 acr-5 Buffer-Buffer-Buffer naive 20240718-ZC3368-naive-buffer-buffer-30s-worm005 ALA []
# No data for N2 acr-5 Buffer-Buffer-Buffer naive 20240718-ZC3368-naive-buffer-buffer-30s-worm005 ASG []
# No data for N2 acr-5 Buffer-Buffer-Buffer naive 20240718-ZC3368-naive-buffer-buffer-30s-worm005 AVD []
# No data for N2 acr-5 Buffer-Buffer-Buffer naive 20240718-ZC3368-naive-buffer-buffer-30s-worm005 AVF []
# No data for N2 acr-5 Buffer-Buffer-Buffer naive 20240718-ZC3368-naive-buffer-buffer-30s-worm005 AVG []
# No data for N2 acr-5 Buffer-Buffer-Buffer naive 20240718-ZC3368-naive-buffer-buffer-30s-worm005 AVH []
# No data for N2 acr-5 Buffer-Buffer-Buffer naive 20240718-ZC3368-naive-buffer-buffer-30s-worm005 DB01 []
# No data for N2 acr-5 Buffer-Buffer-Buffer naive 20240718-ZC3368-naive-buffer-buffer-30s-worm005 SMDV []
# No data for N2 acr-5 Buffer-Buffer-Buffer naive 20240718-ZC3368-naive-buffer-buffer-30s-worm005 VB01 []
# No data for N2 acr-5 Buffer-Buffer-Buffer naive 20240718-ZC3368-naive-buffer-buffer-30s-worm005 VB02 []
# No data for N2 acr-5 Buffer-Buffer-Buffer trained 20240612-ZC3368-trained-buffer-buffer-30s-worm001 ADA []
# No data for N2 acr-5 Buffer-Buffer-Buffer trained 20240612-ZC3368-trained-buffer-buffer-30s-worm001 AVD []
# No data for N2 acr-5 Buffer-Buffer-Buffer trained 20240612-ZC3368-trained-buffer-buffer-30s-worm001 AVH []
# No data for N2 acr-5 Buffer-Buffer-Buffer trained 20240612-ZC3368-trained-buffer-buffer-30s-worm001 VB01 []
# No data for N2 acr-5 Buffer-Buffer-Buffer trained 20240612-ZC3368-trained-buffer-buffer-30s-worm005 ADA []
# No data for N2 acr-5 Buffer-Buffer-Buffer trained 20240612-ZC3368-trained-buffer-buffer-30s-worm005 AIM []
# No data for N2 acr-5 Buffer-Buffer-Buffer trained 20240612-ZC3368-trained-buffer-buffer-30s-worm005 ASG []
# No data for N2 acr-5 Buffer-Buffer-Buffer trained 20240612-ZC3368-trained-buffer-buffer-30s-worm005 AVD []
# No data for N2 acr-5 Buffer-Buffer-Buffer trained 20240612-ZC3368-trained-buffer-buffer-30s-worm005 AVH []
# No data for N2 acr-5 Buffer-Buffer-Buffer trained 20240612-ZC3368-trained-buffer-buffer-30s-worm005 SMDV []
# No data for N2 acr-5 Buffer-Buffer-Buffer trained 20240718-ZC3368-trained-buffer-buffer-30s-worm001 ADA []
# No data for N2 acr-5 Buffer-Buffer-Buffer trained 20240718-ZC3368-trained-buffer-buffer-30s-worm001 AIM []
# No data for N2 acr-5 Buffer-Buffer-Buffer trained 20240718-ZC3368-trained-buffer-buffer-30s-worm001 AVF []
# No data for N2 acr-5 Buffer-Buffer-Buffer trained 20240718-ZC3368-trained-buffer-buffer-30s-worm001 DB01 []
# No data for N2 acr-5 Buffer-Buffer-Buffer trained 20240718-ZC3368-trained-buffer-buffer-30s-worm001 SMDV []
# No data for N2 acr-5 Buffer-Buffer-Buffer trained 20240718-ZC3368-trained-buffer-buffer-30s-worm005 DB01 []
# No data for N2 acr-5 Buffer-Buffer-Buffer trained 20240718-ZC3368-trained-buffer-buffer-30s-worm005 SMDV []
# No data for N2 inx-4+mbr-1 OP-PA-OP naive inx-4+mbr-1p 20221011 naive-worm6 AVJ []
# No data for N2 inx-4+mbr-1 OP-PA-OP naive inx-4+mbr-1p 20221011 naive-worm6 FLP []
# No data for N2 inx-4+mbr-1 OP-PA-OP naive inx-4+mbr-1p 20221011 naive-worm6 RIP []
# No data for N2 inx-4+mbr-1 OP-PA-OP naive inx-4+mbr-1p 20221012 naive-worm3 AIM []
# No data for N2 inx-4+mbr-1 OP-PA-OP naive inx-4+mbr-1p 20221012 naive-worm3 IL1 []
# No data for N2 inx-4+mbr-1 OP-PA-OP naive inx-4+mbr-1p 20221012 naive-worm3 RIP []
# No data for N2 inx-4+mbr-1 OP-PA-OP naive inx-4+mbr-1p 20221012 naive-worm3 RIR []
# No data for N2 inx-4+mbr-1 OP-PA-OP naive inx-4+mbr-1p 20221013naive-worm2 RIR []
# No data for N2 inx-4+mbr-1 OP-PA-OP naive inx-4+mbr-1p image 20221006naive-worm2 AVJ []
# No data for N2 inx-4+mbr-1 OP-PA-OP naive inx-4+mbr-1p image 20221006naive-worm2 RIP []
# No data for N2 inx-4+mbr-1 OP-PA-OP trained inx-4+mbr-1p 20221014trained-worm4 AVJ []
# No data for N2 inx-4+mbr-1 OP-PA-OP trained inx-4+mbr-1p 20221014trained-worm4 IL1 []
# No data for N2 inx-4+mbr-1 OP-PA-OP trained inx-4+mbr-1p 20221014trained-worm4 RIR []
# No data for N2 inx-4+mbr-1 OP-PA-OP trained inx-4+mbr-1p 20221014trained-worm5 IL1 []
# No data for N2 inx-4+mbr-1 OP-PA-OP trained inx-4+mbr-1p image 20221004trained-worm2 AVJ []
# No data for N2 inx-4+mbr-1 OP-PA-OP trained inx-4+mbr-1p image 20221004trained-worm2 RIP []
# No data for N2 inx-4+mbr-1 OP-PA-OP trained inx-4+mbr-1p image 20221004trained-worm2 RIR []
# No data for N2 inx-4+mbr-1 Buffer-PA-Buffer naive 20220831-mbr-1-inx-4p-naive-PA-Buffer-30s-worm02 RIG []
# No data for N2 inx-4+mbr-1 Buffer-PA-Buffer naive 20220901-mbr-1-inx-4p-naive-PA-Buffer-30s-worm004 RIP []
# No data for N2 inx-4+mbr-1 Buffer-PA-Buffer naive 20220901-mbr-1-inx-4p-naive-PA-Buffer-30s-worm005 AIM []
# No data for N2 inx-4+mbr-1 Buffer-PA-Buffer naive 20220901-mbr-1-inx-4p-naive-PA-Buffer-30s-worm005 ASG []
# No data for N2 inx-4+mbr-1 Buffer-PA-Buffer naive 20220901-mbr-1-inx-4p-naive-PA-Buffer-30s-worm005 ASH []
# No data for N2 inx-4+mbr-1 Buffer-PA-Buffer naive 20220901-mbr-1-inx-4p-naive-PA-Buffer-30s-worm005 AVJ []
# No data for N2 inx-4+mbr-1 Buffer-PA-Buffer naive 20220901-mbr-1-inx-4p-naive-PA-Buffer-30s-worm005 FLP []
# No data for N2 inx-4+mbr-1 Buffer-PA-Buffer naive 20220901-mbr-1-inx-4p-naive-PA-Buffer-30s-worm005 OLL []
# No data for N2 inx-4+mbr-1 Buffer-PA-Buffer naive 20220901-mbr-1-inx-4p-naive-PA-Buffer-30s-worm005 RIP []
# No data for N2 inx-4+mbr-1 Buffer-PA-Buffer naive 20220914-inx-4+mbr-1p-naive-PA-Buffer-worm2 ASG []
# No data for N2 inx-4+mbr-1 Buffer-PA-Buffer naive 20220914-inx-4+mbr-1p-naive-PA-Buffer-worm2 AVJ []
# No data for N2 inx-4+mbr-1 Buffer-PA-Buffer trained 20220914-mbr-1-inx-4p-trained-PA-Buffer-30s-worm01 RIP []
# No data for N2 inx-4+mbr-1 Buffer-PA-Buffer trained 20220914-mbr-1-inx-4p-trained-PA-Buffer-30s-worm01 RIR []
# No data for N2 inx-4+mbr-1 Buffer-PA-Buffer trained 20220915-mbr-1-inx-4p-trained-PA-Buffer-30s-worm01 AVJ []
# No data for N2 inx-4+mbr-1 Buffer-PA-Buffer trained 20220916-inx-4+mbr-1p-trained-PA-Buffer-worm2 ASG []
# No data for N2 inx-4+mbr-1 Buffer-PA-Buffer trained 20220916-inx-4+mbr-1p-trained-PA-Buffer-worm2 AVJ []
# No data for N2 inx-4+mbr-1 Buffer-PA-Buffer trained 20220916-inx-4+mbr-1p-trained-PA-Buffer-worm2 RIP []
# No data for N2 inx-4+mbr-1 Buffer-Buffer-Buffer naive 20240808-zc3666-naive-buffer-buffer-30s-worm002 RIR []
# No data for N2 inx-4+mbr-1 Buffer-Buffer-Buffer naive 20240813-ZC3666-naive-buffer-buffer-30s-worm001 ASG []
# No data for N2 inx-4+mbr-1 Buffer-Buffer-Buffer naive 20240813-ZC3666-naive-buffer-buffer-30s-worm001 AVJ []
# No data for N2 inx-4+mbr-1 Buffer-Buffer-Buffer naive 20240813-ZC3666-naive-buffer-buffer-30s-worm001 RIR []
# No data for N2 inx-4+mbr-1 Buffer-Buffer-Buffer naive 20240813-ZC3666-naive-buffer-buffer-30s-worm004 ASG []
# No data for N2 inx-4+mbr-1 Buffer-Buffer-Buffer naive 20240813-ZC3666-naive-buffer-buffer-30s-worm004 RIP []
# No data for N2 inx-4+mbr-1 Buffer-Buffer-Buffer naive 20240813-ZC3666-naive-buffer-buffer-30s-worm005 AIM []
# No data for N2 inx-4+mbr-1 Buffer-Buffer-Buffer naive 20240813-ZC3666-naive-buffer-buffer-30s-worm005 ASG []
# No data for N2 inx-4+mbr-1 Buffer-Buffer-Buffer naive 20240813-ZC3666-naive-buffer-buffer-30s-worm005 AVJ []
# No data for N2 inx-4+mbr-1 Buffer-Buffer-Buffer naive 20240813-ZC3666-naive-buffer-buffer-30s-worm005 RIP []
# No data for N2 inx-4+mbr-1 Buffer-Buffer-Buffer trained 20240813-ZC3666-trained-buffer-buffer-30s-worm001 ASG []
# No data for N2 inx-4+mbr-1 Buffer-Buffer-Buffer trained 20240813-ZC3666-trained-buffer-buffer-30s-worm001 AVJ []
# No data for N2 inx-4+mbr-1 Buffer-Buffer-Buffer trained 20240813-ZC3666-trained-buffer-buffer-30s-worm001 OLL []
# No data for N2 inx-4+mbr-1 Buffer-Buffer-Buffer trained 20240813-ZC3666-trained-buffer-buffer-30s-worm001 RIP []
# No data for N2 inx-4+mbr-1 Buffer-Buffer-Buffer trained 20240813-ZC3666-trained-buffer-buffer-30s-worm001 RIR []
# No data for N2 inx-4+mbr-1 Buffer-Buffer-Buffer trained 20240813-ZC3666-trained-buffer-buffer-30s-worm003 ASG []
# No data for N2 inx-4+mbr-1 Buffer-Buffer-Buffer trained 20240813-ZC3666-trained-buffer-buffer-30s-worm003 AVJ []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p OP-PA-OP naive 20240304-zc4061-naive-OP-PA-30s-worm002 AVF []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p OP-PA-OP naive 20240312-ZC4061-naive-OP-PA-30s-worm004 AVF []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p OP-PA-OP trained 20240307-zc4061-trained-OP-PA-30s-worm004 AVF []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p OP-PA-OP trained 20240307-zc4061-trained-OP-PA-30s-worm004 AVG []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p OP-PA-OP trained 20240307-zc4061-trained-OP-PA-30s-worm004 SAAV []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p OP-PA-OP trained 20240312-ZC4061-trained-OP-PA-30s-worm002 SAAD []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p OP-PA-OP trained 20240402-ZC4061-trained-OP-PA-30s-worm003 SAAD []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p Buffer-PA-Buffer naive 20240116-PA-Buffer-naive-worm1 AVF []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p Buffer-PA-Buffer naive 20240116-PA-Buffer-naive-worm1 RME []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p Buffer-PA-Buffer naive 20240116-PA-Buffer-naive-worm1 SAAD []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p Buffer-PA-Buffer naive 20240116-PA-Buffer-naive-worm1 SIBD []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p Buffer-PA-Buffer naive 20240116-PA-Buffer-naive-worm1 SIBV []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p Buffer-PA-Buffer naive 20240123-PA-Buffer-naive-worm1 AVD []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p Buffer-PA-Buffer naive 20240123-PA-Buffer-naive-worm1 RME []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p Buffer-PA-Buffer naive 20240123-PA-Buffer-naive-worm1 SAAD []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p Buffer-PA-Buffer naive 20240123-PA-Buffer-naive-worm1 SIBD []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p Buffer-PA-Buffer naive 20240123-PA-Buffer-naive-worm1 SMDV []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p Buffer-PA-Buffer naive 20240124-PA-Buffer-naive-worm6 SAAD []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p Buffer-PA-Buffer naive ZC4061_20240125_naive_PA_buffer_worm1 RME []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p Buffer-PA-Buffer trained 20240123-PA-Buffer-trained-worm3 RME []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p Buffer-PA-Buffer trained 20240123-PA-Buffer-trained-worm3 SAAD []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p Buffer-PA-Buffer trained 20240123-PA-Buffer-trained-worm3 SAAV []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p Buffer-PA-Buffer trained 20240123-PA-Buffer-trained-worm3 SIBD []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p Buffer-PA-Buffer trained 20240123-PA-Buffer-trained-worm3 SIBV []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p Buffer-PA-Buffer trained 20240123-PA-Buffer-trained-worm4 AVF []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p Buffer-PA-Buffer trained 20240123-PA-Buffer-trained-worm4 SAAV []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p Buffer-PA-Buffer trained 20240123-PA-Buffer-trained-worm4 SIBD []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p Buffer-PA-Buffer trained ZC4061_20240125_trained_PA_buffer_worm2 AVD []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p Buffer-PA-Buffer trained ZC4061_20240125_trained_PA_buffer_worm2 AVF []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p Buffer-PA-Buffer trained ZC4061_20240125_trained_PA_buffer_worm2 IL1 []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p Buffer-PA-Buffer trained ZC4061_20240125_trained_PA_buffer_worm2 RIM []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p Buffer-PA-Buffer trained ZC4061_20240125_trained_PA_buffer_worm2 RME []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p Buffer-PA-Buffer trained ZC4061_20240125_trained_PA_buffer_worm2 SAAV []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p Buffer-PA-Buffer trained ZC4061_20240125_trained_PA_buffer_worm2 SIBD []
# No data for N2 flp-3p+flp-7p+nmr-1p+sro-1p Buffer-PA-Buffer trained ZC4061_20240125_trained_PA_buffer_worm2 SMDV []
# No data for N2 odr-2(2b)+odr-2(18)p OP-PA-OP naive 20250423-ZC4164-Naive-OP-PA-worm003 ASG []
# No data for N2 odr-2(2b)+odr-2(18)p OP-PA-OP naive 20250423-ZC4164-Naive-OP-PA-worm003 RIV []
# No data for N2 odr-2(2b)+odr-2(18)p OP-PA-OP naive 20250423-ZC4164-Naive-OP-PA-worm003 SIAD []
# No data for N2 odr-2(2b)+odr-2(18)p OP-PA-OP naive 20250429-ZC4164-Naive-OP-PA-30s-worm008 IL1D []
# No data for N2 odr-2(2b)+odr-2(18)p OP-PA-OP naive 20250429-ZC4164-Naive-OP-PA-worm003 IL1V []
# No data for N2 odr-2(2b)+odr-2(18)p OP-PA-OP naive 20250429-ZC4164-Naive-OP-PA-worm003 SIAD []
# No data for N2 odr-2(2b)+odr-2(18)p OP-PA-OP naive 20250430-ZC4164-Naive-OP-PA-worm001 AVG []
# No data for N2 odr-2(2b)+odr-2(18)p OP-PA-OP naive 20250430-ZC4164-Naive-OP-PA-worm001 SIAD []
# No data for N2 odr-2(2b)+odr-2(18)p OP-PA-OP trained 20250429-ZC4164-Trained-OP-PA-worm002 ASG []
# No data for N2 odr-2(2b)+odr-2(18)p OP-PA-OP trained 20250429-ZC4164-Trained-OP-PA-worm002 RIV []
# No data for N2 odr-2(2b)+odr-2(18)p Buffer-PA-Buffer naive 20250408-ZC4164-naive-PA-Buffer-30s-worm004 SIAD []
# No data for N2 odr-2(2b)+odr-2(18)p Buffer-PA-Buffer naive 20250409-ZC4164-naive-PA-Buffer-30s-worm003 SMBD []
# No data for N2 odr-2(2b)+odr-2(18)p Buffer-PA-Buffer naive 20250422-ZC4164-naive-PA-buffer-30s-worm003 SIAD []
# No data for N2 odr-2(2b)+odr-2(18)p Buffer-PA-Buffer trained 20250408-ZC4164-trained-PA-Buffer-30s-worm001 OLL []
# No data for N2 odr-2(2b)+odr-2(18)p Buffer-PA-Buffer trained 20250408-ZC4164-trained-PA-Buffer-30s-worm001 RIV []
# No data for N2 odr-2(2b)+odr-2(18)p Buffer-PA-Buffer trained 20250408-ZC4164-trained-PA-Buffer-30s-worm001 SIAD []
# No data for N2 odr-2(2b)+odr-2(18)p Buffer-PA-Buffer trained 20250409-ZC4164-trained-PA-Buffer-30s-worm002 SIAD []
# No data for N2 odr-2(2b)+odr-2(18)p Buffer-PA-Buffer trained 20250422-ZC4164-trained-PA-buffer-30s-worm004 RIV []
# No data for N2 odr-2(2b)+odr-2(18)p Buffer-Buffer-Buffer naive 20240806-ZC4164-naive-buffer-buffer-30s-worm003 AIY []
# No data for N2 odr-2(2b)+odr-2(18)p Buffer-Buffer-Buffer naive 20240806-ZC4164-naive-buffer-buffer-30s-worm003 ASG []
# No data for N2 odr-2(2b)+odr-2(18)p Buffer-Buffer-Buffer naive 20240806-ZC4164-naive-buffer-buffer-30s-worm003 AVG []
# No data for N2 odr-2(2b)+odr-2(18)p Buffer-Buffer-Buffer naive 20240806-ZC4164-naive-buffer-buffer-30s-worm003 RIV []
# No data for N2 odr-2(2b)+odr-2(18)p Buffer-Buffer-Buffer naive 20240806-ZC4164-naive-buffer-buffer-30s-worm003 SIAD []
# No data for N2 odr-2(2b)+odr-2(18)p Buffer-Buffer-Buffer naive 20240820-odr-2(2b+18)-L1-naive-buffer-buffer-30s-worm003 AIY []
# No data for N2 odr-2(2b)+odr-2(18)p Buffer-Buffer-Buffer naive 20240820-odr-2(2b+18)-L1-naive-buffer-buffer-30s-worm003 ASG []
# No data for N2 odr-2(2b)+odr-2(18)p Buffer-Buffer-Buffer naive 20240820-odr-2(2b+18)-L1-naive-buffer-buffer-30s-worm003 RIV []
# No data for N2 odr-2(2b)+odr-2(18)p Buffer-Buffer-Buffer naive 20240820-odr-2(2b+18)-L1-naive-buffer-buffer-30s-worm003 SIAD []
# No data for N2 odr-2(2b)+odr-2(18)p Buffer-Buffer-Buffer naive 20240820-odr-2(2b+18)-L1-naive-buffer-buffer-30s-worm005 AIY []
# No data for N2 odr-2(2b)+odr-2(18)p Buffer-Buffer-Buffer naive 20240820-odr-2(2b+18)-L1-naive-buffer-buffer-30s-worm005 RIV []
# No data for N2 odr-2(2b)+odr-2(18)p Buffer-Buffer-Buffer trained 20240806-ZC4164-trained-buffer-buffer-30s-worm003 AVG []
# No data for N2 odr-2(2b)+odr-2(18)p Buffer-Buffer-Buffer trained 20240806-ZC4164-trained-buffer-buffer-30s-worm003 OLL []
# No data for N2 odr-2(2b)+odr-2(18)p Buffer-Buffer-Buffer trained 20240806-ZC4164-trained-buffer-buffer-30s-worm003 RIF []
# No data for N2 odr-2(2b)+odr-2(18)p Buffer-Buffer-Buffer trained 20240820-odr-2(2b+18)-L1-trained-buffer-buffer-30s-worm002 AIY []
# No data for N2 odr-2(2b)+odr-2(18)p Buffer-Buffer-Buffer trained 20240820-odr-2(2b+18)-L1-trained-buffer-buffer-30s-worm002 AIZ []
# No data for N2 odr-2(2b)+odr-2(18)p Buffer-Buffer-Buffer trained 20240820-odr-2(2b+18)-L1-trained-buffer-buffer-30s-worm002 SIAD []
# No data for N2 odr-2(2b)+odr-2(18)p Buffer-Buffer-Buffer trained 20240820-odr-2(2b+18)-L1-trained-buffer-buffer-30s-worm002 SMBV []
# No data for N2 odr-2(2b)+odr-2(18)p Buffer-Buffer-Buffer trained 20250324-ZC4164-trained-buffer-buffer-30s-worm03 IL1D []
# No data for N2 odr-2(2b)+odr-2(18)p Buffer-Buffer-Buffer trained 20250324-ZC4164-trained-buffer-buffer-30s-worm03 RIV []
# No data for N2 odr-2(2b)+odr-2(18)p Buffer-Buffer-Buffer trained 20250324-ZC4164-trained-buffer-buffer-30s-worm03 SIAD []
# No data for N2 odr-2(2b)+odr-2(18)p Buffer-Buffer-Buffer trained 20250324-ZC4164-trained-buffer-buffer-30s-worm04 AIY []
# No data for N2 odr-2(2b)+odr-2(18)p Buffer-Buffer-Buffer trained 20250324-ZC4164-trained-buffer-buffer-30s-worm04 SIAD []
# No data for inx-7-mutant ncs-1 OP-PA-OP naive 20241126-ZC4255-naive-OP-PA-30s-worm01 ASI []
# No data for inx-7-mutant ncs-1 OP-PA-OP naive 20241126-ZC4255-naive-OP-PA-30s-worm01 RMG []
# No data for inx-7-mutant ncs-1 OP-PA-OP naive 20241126-ZC4255-naive-OP-PA-30s-worm01 SAAD []
# No data for inx-7-mutant ncs-1 OP-PA-OP naive 20241204-ZC4255-naive-OP-PA-30s-worm003 ASEL []
# No data for inx-7-mutant ncs-1 OP-PA-OP naive 20250501-ZC4255-naive-OP-PA-30s-worm002 ASER []
# No data for inx-7-mutant ncs-1 OP-PA-OP naive 20250501-ZC4255-naive-OP-PA-30s-worm002 ASI []
# No data for inx-7-mutant ncs-1 OP-PA-OP naive 20250501-ZC4255-naive-OP-PA-30s-worm002 AVK []
# No data for inx-7-mutant ncs-1 OP-PA-OP naive 20250501-ZC4255-naive-OP-PA-30s-worm002 RMG []
# No data for inx-7-mutant ncs-1 OP-PA-OP naive 20250501-ZC4255-naive-OP-PA-30s-worm002 SAAD []
# No data for inx-7-mutant ncs-1 OP-PA-OP trained 20241204-ZC4255-trained-OP-PA-30s-worm003 ADF []
# No data for inx-7-mutant ncs-1 OP-PA-OP trained 20241204-ZC4255-trained-OP-PA-30s-worm003 RMG []
# No data for inx-7-mutant ncs-1 OP-PA-OP trained 20250501-ZC4255-trained-OP-PA-30s-worm002 AFD []
# No data for inx-7-mutant ncs-1 OP-PA-OP trained 20250501-ZC4255-trained-OP-PA-30s-worm002 AWA []
# No data for inx-7-mutant ncs-1 OP-PA-OP trained 20250501-ZC4255-trained-OP-PA-30s-worm002 RMG []
# No data for inx-7-mutant ncs-1 OP-PA-OP trained 20250507-ZC4255-trained-OP-PA-30s-worm001 ADF []
# No data for inx-7-mutant ncs-1 OP-PA-OP trained 20250507-ZC4255-trained-OP-PA-30s-worm001 ASEL []
# No data for inx-7-mutant ncs-1 OP-PA-OP trained 20250507-ZC4255-trained-OP-PA-30s-worm001 ASI []
# No data for inx-7-mutant ncs-1 OP-PA-OP trained 20250507-ZC4255-trained-OP-PA-30s-worm001 AWA []
# No data for inx-7-rescue ncs-1 OP-PA-OP naive 20241126-ZC4251-naive-OP-PA-30s-worm001 AIY []
# No data for inx-7-rescue ncs-1 OP-PA-OP naive 20241126-ZC4251-naive-OP-PA-30s-worm001 ASH []
# No data for inx-7-rescue ncs-1 OP-PA-OP naive 20241126-ZC4251-naive-OP-PA-30s-worm001 RMG []
# No data for inx-7-rescue ncs-1 OP-PA-OP naive 20241126-ZC4251-naive-OP-PA-30s-worm001 SAAD []
# No data for inx-7-rescue ncs-1 OP-PA-OP naive 20241204-ZC4251-naive-OP-PA-30s-worm002 AIY []
# No data for inx-7-rescue ncs-1 OP-PA-OP naive 20241204-ZC4251-naive-OP-PA-30s-worm002 RMG []
# No data for inx-7-rescue ncs-1 OP-PA-OP naive 20250501-ZC4251-naive-OP-PA-30s-worm001 ADF []
# No data for inx-7-rescue ncs-1 OP-PA-OP naive 20250501-ZC4251-naive-OP-PA-30s-worm001 AIY []
# No data for inx-7-rescue ncs-1 OP-PA-OP naive 20250501-ZC4251-naive-OP-PA-30s-worm001 ASEL []
# No data for inx-7-rescue ncs-1 OP-PA-OP naive 20250501-ZC4251-naive-OP-PA-30s-worm001 ASH []
# No data for inx-7-rescue ncs-1 OP-PA-OP naive 20250501-ZC4251-naive-OP-PA-30s-worm001 ASI []
# No data for inx-7-rescue ncs-1 OP-PA-OP naive 20250501-ZC4251-naive-OP-PA-30s-worm001 AVK []
# No data for inx-7-rescue ncs-1 OP-PA-OP naive 20250501-ZC4251-naive-OP-PA-30s-worm001 SAAD []
# No data for inx-7-rescue ncs-1 OP-PA-OP naive 20250501-ZC4251-naive-OP-PA-30s-worm001 SAAV []
# No data for inx-7-rescue ncs-1 OP-PA-OP naive raw_results-20241126-ZC4251-naive-PA-OP-30s-worm002 ADF []
# No data for inx-7-rescue ncs-1 OP-PA-OP naive raw_results-20241126-ZC4251-naive-PA-OP-30s-worm002 ASEL []
# No data for inx-7-rescue ncs-1 OP-PA-OP naive raw_results-20241126-ZC4251-naive-PA-OP-30s-worm002 ASH []
# No data for inx-7-rescue ncs-1 OP-PA-OP trained 20241126-ZC4251-trained-OP-PA-30s-worm02 ADF []
# No data for inx-7-rescue ncs-1 OP-PA-OP trained 20241126-ZC4251-trained-OP-PA-30s-worm02 AIY []
# No data for inx-7-rescue ncs-1 OP-PA-OP trained 20241126-ZC4251-trained-OP-PA-30s-worm02 ASH []
# No data for inx-7-rescue ncs-1 OP-PA-OP trained 20241126-ZC4251-trained-OP-PA-30s-worm02 ASI []
# No data for inx-7-rescue ncs-1 OP-PA-OP trained 20241126-ZC4251-trained-OP-PA-30s-worm02 RMG []
# No data for inx-7-rescue ncs-1 OP-PA-OP trained 20241205-ZC4251-trained-OP-PA-30s-worm001 ADF []
# No data for inx-7-rescue ncs-1 OP-PA-OP trained 20241205-ZC4251-trained-OP-PA-30s-worm001 ASEL []
# No data for inx-7-rescue ncs-1 OP-PA-OP trained 20241205-ZC4251-trained-OP-PA-30s-worm001 ASI []
# No data for inx-7-rescue ncs-1 OP-PA-OP trained 20250507-ZC4251-trained-OP-PA-30s-worm002 ADF []
# No data for inx-7-rescue ncs-1 OP-PA-OP trained 20250507-ZC4251-trained-OP-PA-30s-worm002 AIY []
# No data for inx-7-rescue ncs-1 OP-PA-OP trained 20250507-ZC4251-trained-OP-PA-30s-worm002 AVK []
# No data for inx-7-rescue ncs-1 OP-PA-OP trained 20250507-ZC4251-trained-OP-PA-30s-worm003 ASI []

# %%
for genotype in worm_tensors:
    for promoter in worm_tensors[genotype]:
        for stimulus in worm_tensors[genotype][promoter]:
            for cond in worm_tensors[genotype][promoter][stimulus]:
                if np.isnan(worm_tensors[genotype][promoter][stimulus][cond]).all():
                    print("NaN in tensor", genotype, promoter, stimulus, cond)
                    print(np.shape(worm_tensors[genotype][promoter][stimulus][cond]))
                    continue
                for j in range(worm_tensors[genotype][promoter][stimulus][cond].shape[0]):
                    if np.isnan(worm_tensors[genotype][promoter][stimulus][cond][j]).all():
                        print("All NaN in tensor", genotype, promoter, stimulus, cond, all_neurs_set[genotype][promoter][stimulus][j])

# %%
## Initial imputation
worm_tensors_pre_imputed =  {}
for genotype in worm_tensors:
    worm_tensors_pre_imputed[genotype] = {}
    for promoter in worm_tensors[genotype]:
        worm_tensors_pre_imputed[genotype][promoter] = {}
        for stimulus in worm_tensors[genotype][promoter]:
            worm_tensors_pre_imputed[genotype][promoter][stimulus] = {}
            for cond in worm_tensors[genotype][promoter][stimulus]:
                worm_tensors_pre_imputed[genotype][promoter][stimulus][cond] = np.empty((len(all_neurs_set[genotype][promoter][stimulus]), num_timepoints, worm_tensors[genotype][promoter][stimulus][cond].shape[2]))
                worm_tensors_pre_imputed[genotype][promoter][stimulus][cond].fill(np.nan)
                for n in range(len(all_neurs_set[genotype][promoter][stimulus])):
                    for w in range(worm_tensors[genotype][promoter][stimulus][cond].shape[2]):
                        if not np.isnan(worm_tensors[genotype][promoter][stimulus][cond][n, :, w]).all():
                            worm_tensors_pre_imputed[genotype][promoter][stimulus][cond][n, :, w] = worm_tensors[genotype][promoter][stimulus][cond][n, :, w]
                        else:
                            # Calculate the mean activity of the same neuron from other worms
                            print("Is all nans", all_neurs_set[genotype][promoter][stimulus][n], np.isnan(worm_tensors[genotype][promoter][stimulus][cond][n, :, :]).all())
                            median_value = np.nanmedian(worm_tensors[genotype][promoter][stimulus][cond][n, :, :], axis=1)
                            worm_tensors_pre_imputed[genotype][promoter][stimulus][cond][n, :, w] = median_value
# Out:
# Is all nans ADF False
# Is all nans ADL False
# Is all nans ADL False
# Is all nans ADL False
# Is all nans AIY False
# Is all nans AIY False
# Is all nans AIY False
# Is all nans ASEL False
# Is all nans ASH False
# Is all nans ASH False
# Is all nans AVK False
# Is all nans RMG False
# Is all nans RMG False
# Is all nans RMG False
# Is all nans SAAD False
# Is all nans SAAD False
# Is all nans ADF False
# Is all nans ADL False
# Is all nans ADL False
# Is all nans AIY False
# Is all nans AIY False
# Is all nans AIY False
# Is all nans ASER False
# Is all nans ASH False
# Is all nans ASH False
# Is all nans ASI False
# Is all nans RMG False
# Is all nans RMG False
# Is all nans SAAD False
# Is all nans SAAD False
# Is all nans AFD False
# Is all nans AFD False
# Is all nans ASER False
# Is all nans ASI False
# Is all nans ASI False
# Is all nans BAG False
# Is all nans OLL False
# Is all nans RMG False
# Is all nans RMG False
# Is all nans RMG False
# Is all nans SAAD False
# Is all nans SAAD False
# Is all nans SAAV False
# Is all nans ADF False
# Is all nans ADF False
# Is all nans AFD False
# Is all nans ASER False
# Is all nans ASI False
# Is all nans AWA False
# Is all nans RMG False
# Is all nans RMG False
# Is all nans RMG False
# Is all nans SAAD False
# Is all nans SAAD False
# Is all nans SAAD False
# Is all nans ADF False
# Is all nans ASEL False
# Is all nans ASER False
# Is all nans ASG False
# Is all nans ASH False
# Is all nans ASH False
# Is all nans ASH False
# Is all nans ASI False
# Is all nans ASI False
# Is all nans ASI False
# Is all nans AVK False
# Is all nans AWA False
# Is all nans AWA False
# Is all nans AWB False
# Is all nans OLL False
# Is all nans RMG False
# Is all nans RMG False
# Is all nans RMG False
# Is all nans SAAD False
# Is all nans ASEL False
# Is all nans ASER False
# Is all nans ASER False
# Is all nans ASER False
# Is all nans ASH False
# Is all nans ASH False
# Is all nans ASI False
# Is all nans ASI False
# Is all nans AWA False
# Is all nans BAG False
# Is all nans OLL False
# Is all nans RMG False
# Is all nans RMG False
# Is all nans RMG False
# Is all nans ASER False
# Is all nans ASH False
# Is all nans OLL False
# Is all nans RMG False
# Is all nans RMG False
# Is all nans ASER False
# Is all nans ASH False
# Is all nans ASH False
# Is all nans ASH False
# Is all nans ASI False
# Is all nans ASI False
# Is all nans ASI False
# Is all nans AWA False
# Is all nans OLL False
# Is all nans RMG False
# Is all nans RMG False
# Is all nans RMG False
# Is all nans SAAD False
# Is all nans SAAV False
# Is all nans ASEL False
# Is all nans ASEL False
# Is all nans ASH False
# Is all nans ASH False
# Is all nans ASH False
# Is all nans ASI False
# Is all nans ASI False
# Is all nans AVK False
# Is all nans AVK False
# Is all nans AWA False
# Is all nans AWA False
# Is all nans AWA False
# Is all nans AWB False
# Is all nans AWC False
# Is all nans OLL False
# Is all nans SAAV False
# Is all nans SAAV False
# Is all nans AFD False
# Is all nans ASER False
# Is all nans ASER False
# Is all nans ASG False
# Is all nans ASH False
# Is all nans ASH False
# Is all nans AVK False
# Is all nans ASH False
# Is all nans AVJ False
# Is all nans AVJ False
# Is all nans ASH False
# Is all nans ASH False
# Is all nans ASH False
# Is all nans AVJ False
# Is all nans AVJ False
# Is all nans AVJ False
# Is all nans FLP False
# Is all nans OLL False
# Is all nans ASG False
# Is all nans ASG False
# Is all nans ASH False
# Is all nans ASH False
# Is all nans ASH False
# Is all nans FLP False
# Is all nans OLL False
# Is all nans ASG False
# Is all nans ASG False
# Is all nans ASG False
# Is all nans ASH False
# Is all nans ASH False
# Is all nans ASH False
# Is all nans FLP False
# Is all nans FLP False
# Is all nans OLL False
# Is all nans OLL False
# Is all nans AVB False
# Is all nans AVD False
# Is all nans AVD False
# Is all nans AVE False
# Is all nans RIA False
# Is all nans RIA False
# Is all nans RIA False
# Is all nans RMD False
# Is all nans RMDD False
# Is all nans RMDD False
# Is all nans RME False
# Is all nans SMDD False
# Is all nans SMDD False
# Is all nans SMDV False
# Is all nans AVB False
# Is all nans AVD False
# Is all nans RIA False
# Is all nans RIA False
# Is all nans RME False
# Is all nans SMDV False
# Is all nans AVD False
# Is all nans AVE False
# Is all nans AVE False
# Is all nans RIM False
# Is all nans RMD False
# Is all nans RMD False
# Is all nans RMDD False
# Is all nans SMDD False
# Is all nans AVB False
# Is all nans AVD False
# Is all nans AVD False
# Is all nans RIM False
# Is all nans AIB False
# Is all nans AIB False
# Is all nans AIB False
# Is all nans M1 False
# Is all nans RIA False
# Is all nans RIA False
# Is all nans RIA False
# Is all nans SMDV False
# Is all nans AIB False
# Is all nans AIB False
# Is all nans AVB False
# Is all nans AVD False
# Is all nans RIA False
# Is all nans RIA False
# Is all nans RIA False
# Is all nans ALA False
# Is all nans ASG False
# Is all nans AVD False
# Is all nans AVD False
# Is all nans AVD False
# Is all nans AVF False
# Is all nans AVH False
# Is all nans AVH False
# Is all nans CEPD False
# Is all nans CEPV False
# Is all nans DB01 False
# Is all nans OLL False
# Is all nans VB01 False
# Is all nans VB01 False
# Is all nans VB02 False
# Is all nans ALA False
# Is all nans ASG False
# Is all nans ASG False
# Is all nans AVD False
# Is all nans AVD False
# Is all nans AVF False
# Is all nans AVF False
# Is all nans AVG False
# Is all nans AVH False
# Is all nans AVH False
# Is all nans AVH False
# Is all nans CEPD False
# Is all nans CEPV False
# Is all nans DB01 False
# Is all nans DB01 False
# Is all nans DB01 False
# Is all nans OLL False
# Is all nans URAV False
# Is all nans URYV False
# Is all nans VB01 False
# Is all nans VB01 False
# Is all nans VB02 False
# Is all nans ADA False
# Is all nans ALA False
# Is all nans ASG False
# Is all nans AVD False
# Is all nans AVF False
# Is all nans AVF False
# Is all nans AVF False
# Is all nans AVG False
# Is all nans AVG False
# Is all nans CEPD False
# Is all nans DB01 False
# Is all nans DB01 False
# Is all nans VB02 False
# Is all nans ADA False
# Is all nans ADA False
# Is all nans ADA False
# Is all nans ALA False
# Is all nans ALA False
# Is all nans ASG False
# Is all nans AVD False
# Is all nans AVD False
# Is all nans AVD False
# Is all nans AVF False
# Is all nans CEPD False
# Is all nans OLL False
# Is all nans OLL False
# Is all nans URAD False
# Is all nans URAD False
# Is all nans URYD False
# Is all nans VB02 False
# Is all nans ADA False
# Is all nans AIM False
# Is all nans AIM False
# Is all nans ALA False
# Is all nans ASG False
# Is all nans AVD False
# Is all nans AVF False
# Is all nans AVG False
# Is all nans AVH False
# Is all nans DB01 False
# Is all nans SMDV False
# Is all nans VB01 False
# Is all nans VB02 False
# Is all nans ADA False
# Is all nans ADA False
# Is all nans ADA False
# Is all nans AIM False
# Is all nans AIM False
# Is all nans ASG False
# Is all nans AVD False
# Is all nans AVD False
# Is all nans AVF False
# Is all nans AVH False
# Is all nans AVH False
# Is all nans DB01 False
# Is all nans DB01 False
# Is all nans SMDV False
# Is all nans SMDV False
# Is all nans SMDV False
# Is all nans VB01 False
# Is all nans AIM False
# Is all nans AVJ False
# Is all nans AVJ False
# Is all nans FLP False
# Is all nans IL1 False
# Is all nans RIP False
# Is all nans RIP False
# Is all nans RIP False
# Is all nans RIR False
# Is all nans RIR False
# Is all nans AVJ False
# Is all nans AVJ False
# Is all nans IL1 False
# Is all nans IL1 False
# Is all nans RIP False
# Is all nans RIR False
# Is all nans RIR False
# Is all nans AIM False
# Is all nans ASG False
# Is all nans ASG False
# Is all nans ASH False
# Is all nans AVJ False
# Is all nans AVJ False
# Is all nans FLP False
# Is all nans OLL False
# Is all nans RIG False
# Is all nans RIP False
# Is all nans RIP False
# Is all nans ASG False
# Is all nans AVJ False
# Is all nans AVJ False
# Is all nans RIP False
# Is all nans RIP False
# Is all nans RIR False
# Is all nans AIM False
# Is all nans ASG False
# Is all nans ASG False
# Is all nans ASG False
# Is all nans AVJ False
# Is all nans AVJ False
# Is all nans RIP False
# Is all nans RIP False
# Is all nans RIR False
# Is all nans RIR False
# Is all nans ASG False
# Is all nans ASG False
# Is all nans AVJ False
# Is all nans AVJ False
# Is all nans OLL False
# Is all nans RIP False
# Is all nans RIR False
# Is all nans AVF False
# Is all nans AVF False
# Is all nans AVF False
# Is all nans AVG False
# Is all nans SAAD False
# Is all nans SAAD False
# Is all nans SAAV False
# Is all nans AVD False
# Is all nans AVF False
# Is all nans RME False
# Is all nans RME False
# Is all nans RME False
# Is all nans SAAD False
# Is all nans SAAD False
# Is all nans SAAD False
# Is all nans SIBD False
# Is all nans SIBD False
# Is all nans SIBV False
# Is all nans SMDV False
# Is all nans AVD False
# Is all nans AVF False
# Is all nans AVF False
# Is all nans IL1 False
# Is all nans RIM False
# Is all nans RME False
# Is all nans RME False
# Is all nans SAAD False
# Is all nans SAAV False
# Is all nans SAAV False
# Is all nans SAAV False
# Is all nans SIBD False
# Is all nans SIBD False
# Is all nans SIBD False
# Is all nans SIBV False
# Is all nans SMDV False
# Is all nans ASG False
# Is all nans AVG False
# Is all nans IL1D False
# Is all nans IL1V False
# Is all nans RIV False
# Is all nans SIAD False
# Is all nans SIAD False
# Is all nans SIAD False
# Is all nans ASG False
# Is all nans RIV False
# Is all nans SIAD False
# Is all nans SIAD False
# Is all nans SMBD False
# Is all nans OLL False
# Is all nans RIV False
# Is all nans RIV False
# Is all nans SIAD False
# Is all nans SIAD False
# Is all nans AIY False
# Is all nans AIY False
# Is all nans AIY False
# Is all nans ASG False
# Is all nans ASG False
# Is all nans AVG False
# Is all nans RIV False
# Is all nans RIV False
# Is all nans RIV False
# Is all nans SIAD False
# Is all nans SIAD False
# Is all nans AIY False
# Is all nans AIY False
# Is all nans AIZ False
# Is all nans AVG False
# Is all nans IL1D False
# Is all nans OLL False
# Is all nans RIF False
# Is all nans RIV False
# Is all nans SIAD False
# Is all nans SIAD False
# Is all nans SIAD False
# Is all nans SMBV False
# Is all nans ASEL False
# Is all nans ASER False
# Is all nans ASI False
# Is all nans ASI False
# Is all nans AVK False
# Is all nans RMG False
# Is all nans RMG False
# Is all nans SAAD False
# Is all nans SAAD False
# Is all nans ADF False
# Is all nans ADF False
# Is all nans AFD False
# Is all nans ASEL False
# Is all nans ASI False
# Is all nans AWA False
# Is all nans AWA False
# Is all nans RMG False
# Is all nans RMG False
# Is all nans ADF False
# Is all nans ADF False
# Is all nans AIY False
# Is all nans AIY False
# Is all nans AIY False
# Is all nans ASEL False
# Is all nans ASEL False
# Is all nans ASH False
# Is all nans ASH False
# Is all nans ASH False
# Is all nans ASI False
# Is all nans AVK False
# Is all nans RMG False
# Is all nans RMG False
# Is all nans SAAD False
# Is all nans SAAD False
# Is all nans SAAV False
# Is all nans ADF False
# Is all nans ADF False
# Is all nans ADF False
# Is all nans AIY False
# Is all nans AIY False
# Is all nans ASEL False
# Is all nans ASH False
# Is all nans ASI False
# Is all nans ASI False
# Is all nans ASI False
# Is all nans AVK False
# Is all nans RMG False

# %%
## imputation of missing neurons

# Extract the imputed data for each worm
rank = 10  # Choose the rank for the decomposition
worm_tensors_imputed = {}
full_imputed = {}
method = 'parafac'
for genotype in worm_tensors:
    worm_tensors_imputed[genotype] = {}
    for promoter in worm_tensors[genotype]:
        worm_tensors_imputed[genotype][promoter] = {}
        for stimulus in worm_tensors[genotype][promoter]:
            if len(worm_tensors[genotype][promoter][stimulus]):
                worm_tensors_imputed[genotype][promoter][stimulus] = {}
            else:
                continue
            for cond in worm_tensors[genotype][promoter][stimulus]:
                worm_tensors_imputed[genotype][promoter][stimulus][cond] = np.empty((len(all_neurs_set[genotype][promoter][stimulus]), num_timepoints, worm_tensors[genotype][promoter][stimulus][cond].shape[2]))
                worm_tensors_imputed[genotype][promoter][stimulus][cond].fill(np.nan)
                # Perform CP decomposition
                if method == 'parafac':
                    mask = ~np.isnan(worm_tensors[genotype][promoter][stimulus][cond])
                    print(genotype, promoter, stimulus, cond, np.shape(worm_tensors_pre_imputed[genotype][promoter][stimulus][cond]))
                    weights, factors = parafac(worm_tensors_pre_imputed[genotype][promoter][stimulus][cond], rank=rank, init='random', random_state=cedne.RANDOM_SEED, n_iter_max=100, mask=mask)
                    # Reconstruct the tensor with imputed values
                    imputed_tensor = kruskal_to_tensor((weights, factors))
                elif method == 'tucker':
                    weights, factors = tucker(worm_tensors_pre_imputed[genotype][promoter][stimulus][cond], rank=rank, init='random', random_state=cedne.RANDOM_SEED, n_iter_max=100)
                    # Reconstruct the tensor with imputed values
                    imputed_tensor = multi_mode_dot(weights, factors)
                    
                full_imputed[cond] = imputed_tensor

                for n in range(len(all_neurs_set[genotype][promoter][stimulus])):
                    for t in range(num_timepoints):
                        for w in range(worm_tensors[genotype][promoter][stimulus][cond].shape[2]):
                            if np.isnan(worm_tensors[genotype][promoter][stimulus][cond][n, t, w]):
                                worm_tensors_imputed[genotype][promoter][stimulus][cond][n, t, w] = imputed_tensor[n, t, w]
                            else:
                                worm_tensors_imputed[genotype][promoter][stimulus][cond][n, t, w] = worm_tensors[genotype][promoter][stimulus][cond][n, t, w]
# Out:
# N2 ncs-1 OP-PA-OP naive (18, 450, 4)
# N2 ncs-1 OP-PA-OP trained (18, 450, 4)
# N2 ncs-1 OP-Buffer-OP naive (13, 450, 4)
# N2 ncs-1 OP-Buffer-OP trained (13, 450, 4)
# N2 ncs-1 Buffer-PA-Buffer naive (16, 450, 4)
# N2 ncs-1 Buffer-PA-Buffer trained (16, 450, 4)
# N2 ncs-1 Buffer-Buffer-Buffer naive (16, 450, 4)
# N2 ncs-1 Buffer-Buffer-Buffer trained (16, 450, 4)
# N2 ncs-1 OP-gacA-OP naive (14, 450, 4)
# N2 ncs-1 OP-gacA-OP trained (14, 450, 3)
# N2 inx-4 OP-PA-OP naive (8, 450, 3)
# N2 inx-4 OP-PA-OP trained (8, 450, 4)
# N2 inx-4 Buffer-PA-Buffer naive (8, 450, 4)
# N2 inx-4 Buffer-PA-Buffer trained (8, 450, 4)
# N2 glr-1 OP-PA-OP naive (12, 450, 4)
# N2 glr-1 OP-PA-OP trained (12, 450, 4)
# N2 glr-1 Buffer-PA-Buffer naive (10, 450, 4)
# N2 glr-1 Buffer-PA-Buffer trained (10, 450, 3)
# N2 glr-1 Buffer-Buffer-Buffer naive (13, 450, 4)
# N2 glr-1 Buffer-Buffer-Buffer trained (13, 450, 4)
# N2 acr-5 OP-PA-OP naive (16, 450, 4)
# N2 acr-5 OP-PA-OP trained (16, 450, 4)
# N2 acr-5 Buffer-PA-Buffer naive (15, 450, 4)
# N2 acr-5 Buffer-PA-Buffer trained (15, 450, 4)
# N2 acr-5 Buffer-Buffer-Buffer naive (19, 450, 4)
# N2 acr-5 Buffer-Buffer-Buffer trained (19, 450, 4)
# N2 inx-4+mbr-1 OP-PA-OP naive (12, 450, 4)
# N2 inx-4+mbr-1 OP-PA-OP trained (12, 450, 3)
# N2 inx-4+mbr-1 Buffer-PA-Buffer naive (13, 450, 4)
# N2 inx-4+mbr-1 Buffer-PA-Buffer trained (13, 450, 3)
# N2 inx-4+mbr-1 Buffer-Buffer-Buffer naive (12, 450, 4)
# N2 inx-4+mbr-1 Buffer-Buffer-Buffer trained (12, 450, 3)
# N2 flp-3p+flp-7p+nmr-1p+sro-1p OP-PA-OP naive (13, 450, 4)
# N2 flp-3p+flp-7p+nmr-1p+sro-1p OP-PA-OP trained (13, 450, 4)
# N2 flp-3p+flp-7p+nmr-1p+sro-1p Buffer-PA-Buffer naive (15, 450, 4)
# N2 flp-3p+flp-7p+nmr-1p+sro-1p Buffer-PA-Buffer trained (15, 450, 4)
# N2 odr-2(2b)+odr-2(18)p OP-PA-OP naive (15, 450, 4)
# N2 odr-2(2b)+odr-2(18)p OP-PA-OP trained (15, 450, 3)
# N2 odr-2(2b)+odr-2(18)p Buffer-PA-Buffer naive (15, 450, 4)
# N2 odr-2(2b)+odr-2(18)p Buffer-PA-Buffer trained (15, 450, 3)
# N2 odr-2(2b)+odr-2(18)p Buffer-Buffer-Buffer naive (16, 450, 4)
# N2 odr-2(2b)+odr-2(18)p Buffer-Buffer-Buffer trained (16, 450, 4)
# inx-7-mutant ncs-1 OP-PA-OP naive (15, 450, 4)
# inx-7-mutant ncs-1 OP-PA-OP trained (15, 450, 3)
# inx-7-rescue ncs-1 OP-PA-OP naive (17, 450, 4)
# inx-7-rescue ncs-1 OP-PA-OP trained (17, 450, 4)

# %%
def block_to_df(genotype, promoter, stimulus, cond, arr, orig, all_neurs_set):
    if arr.ndim != 3:
        raise ValueError("Expected 3D ndarray")
    N, T, W = arr.shape

    # Worm-major, then neuron, then time: (W, N, T)
    vals = arr.transpose(2, 0, 1).reshape(-1)
    imputed_flag = np.isnan(orig).transpose(2, 0, 1).reshape(-1)

    w_idx = np.repeat(np.arange(W), N * T)
    n_idx = np.tile(np.repeat(np.arange(N), T), W)
    t_idx = np.tile(np.arange(T), N * W)

    names = np.asarray(all_neurs_set[genotype][promoter][stimulus])
    assert names.shape[0] == N

    return pd.DataFrame({
        "genotype": genotype,
        "promoter": promoter,
        "stimulus": stimulus,
        "condition": cond,
        "w": w_idx,
        "n": n_idx,
        "neuron": names[n_idx],
        "t": t_idx,
        "value": vals,
        "imputed": imputed_flag
    })

def save_worm_tensors_imputed_csv(worm_tensors_imputed, worm_tensors_original, all_neurs_set, out_csv):
    frames = []
    for genotype, d1 in worm_tensors_imputed.items():
        for promoter, d2 in d1.items():
            for stimulus, d3 in d2.items():
                for cond, arr in d3.items():
                    orig = worm_tensors_original[genotype][promoter][stimulus][cond]
                    frames.append(block_to_df(genotype, promoter, stimulus, cond, arr, orig, all_neurs_set))

    df = pd.concat(frames, ignore_index=True)
    df.to_csv(out_csv, index=False)
    return df

# %%
df_saved_imputed = save_worm_tensors_imputed_csv(worm_tensors_imputed, worm_tensors, all_neurs_set,"processed/worm_tensors_imputed.csv")

# %%
neuron = 'ADA'
condition = 'naive'
stimulus = 'OP-PA-OP'
# promoter = 'ncs-1'
imputed = False
genotype = 'N2'
val = df_saved_imputed[(df_saved_imputed['imputed']==imputed) & (df_saved_imputed['neuron']==neuron) & (df_saved_imputed['condition']==condition) & (df_saved_imputed['stimulus']==stimulus) & (df_saved_imputed['genotype']==genotype)]

# %%
## Save to pickle
with open (outputDir + 'worm_tensors.pickle', 'wb') as po:
    pickle.dump([all_neurs_set, worm_tensors, worm_tensors_imputed], po)

# %%
for genotype in worm_tensors_imputed:
    for promoter in worm_tensors_imputed[genotype]:
        for stim in worm_tensors_imputed[genotype][promoter]:
            for cond in worm_tensors_imputed[genotype][promoter][stim]:
                arr = worm_tensors_imputed[genotype][promoter][stim][cond]
                for trial in arr:
                    if np.isnan(trial).any():
                        print("NaN found in {genotype} [{promoter}][{stim}][{cond}] trial")

# %%
def build_common_by_promoter(genotypes, all_neurs_set, promoter):
    name_lists = []
    for g in genotypes:
        for stim, lst in all_neurs_set.get(g, {}).get(promoter, {}).items():
            name_lists.append(lst)  # ordered list
    if not name_lists:
        return []
    inter = set(name_lists[0]).intersection(*map(set, name_lists[1:]))
    return [n for n in name_lists[0] if n in inter]  # deterministic order

all_neurs_set_common_across_promoters = {}
common_neurs = {}

for g in genotypes:
    all_neurs_set_common_across_promoters[g] = {}
    for promoter in worm_tensors_imputed.get(g, {}):
        if promoter not in common_neurs:
            common_neurs[promoter] = build_common_by_promoter(genotypes, all_neurs_set, promoter)
        if not common_neurs[promoter]:
            continue

        all_neurs_set_common_across_promoters[g][promoter] = {}
        for stimulus, cond_dict in worm_tensors_imputed[g][promoter].items():
            names_src = all_neurs_set[g][promoter][stimulus]              # ordered source names
            idx_map   = {n:i for i,n in enumerate(names_src)}
            gather    = [idx_map[n] for n in common_neurs[promoter] if n in idx_map]

            all_neurs_set_common_across_promoters[g][promoter][stimulus] = {}
            for cond, arr in cond_dict.items():                            # arr: (N_src, T, W)
                T, W = arr.shape[1], arr.shape[2]
                out = arr[gather, :, :]                                    # gather by names
                all_neurs_set_common_across_promoters[g][promoter][stimulus][cond] = out

with open(outputDir + 'worm_tensors_common_neurs.pickle', 'wb') as po:
    pickle.dump([common_neurs, all_neurs_set_common_across_promoters], po)
